# %% [markdown]
# # Libraries

# %%
import time
import copy

import casadi as ca
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd
from mealpy import FloatVar, PSO
from mealpy.utils.problem import Problem
from mealpy.utils.problem import FloatVar

from scipy.optimize import root_scalar

from mealpy.swarm_based import PSO
from mealpy.utils.problem import FloatVar
import time

# %% [markdown]
# # Experimental data

# %%
df_exp = pd.read_excel('Experimental_data.xlsx', sheet_name='Fitting Data')
t_exp = df_exp['Time (Hours)']
X_exp = df_exp['Biomass (g/L)']
C_exp = df_exp['Glycerol (g/L)']
N_exp = df_exp['Ammonia (g/L)']
ph_exp = df_exp['pH']

# %% [markdown]
# # Parameters

# %%
# Original parameters
params_values = {'t_lag': 7,
      'k_C': 0.3828,
      'k_N': 1.0027e-4, 
      'Y': {'X_C': 0.484,
      'X_N': 21.575, 
      'X_CO2': 0.3687,
      'X_O2' : 1.352}, 
      'Xmax': 1.4462,  
      'mu_max': 0.19,
      'k_d': 0.001, 
      'pH': {'pka1': 6.86, # pKa of KH2PO4
            'pka2': 3.13,  # pka of C6H8O7
            'pka3': 4.76,  # pka of (C6H7O7)-
            'pka4': 6.40,  # pka of (C6H6O7)2-
            'pka5': 9.25,  # pka of NH3
            'pka6': 14.15, # pka of C3H8O3
            'pka7': 6.35,  # pka of CO2
            'pka8': 10.33, # pka of (HCO3)-
            'pka9': 14,    # pka of H2O
            'conc': {'KH2PO4': 2.18,
                  'C6H8O7': 2},
            'LL': 3.4687,
            'UL': 7.4,
            'alk': 7.2},
      'I_val': 4.0413,
      'pH_M': [0, 14],
      'O2_sat' : 0.007267,
      'k_La' : 86.26,
      'k_O' : 0.0045} 

P_og =[ params_values['pH']['UL'],params_values['Xmax']] #,params_values['mu_max'],params_values['I_val']
print(P_og)
# Out:
# [7.4, 1.4462]

# %% [markdown]
# # Equations and Solving

# %%
def DAE_system_CasADi_O2(t, vars, z_algebraic, p, params_values):

      
      X, C, N, CO2, O = vars[0], vars[1], vars[2], vars[3], vars[4]
      w = z_algebraic[0] 
      
      # parameteros que se evaluaron en el estudio, solo UL y Xmax se dejaron variables en relacion al PSO
      UL = p[0] #params_values['pH']['UL']
      Xmax = p[1] #params_values['Xmax']#
      mu_max = params_values['mu_max']
      Y_X_C =params_values['Y']['X_C'] 
      
      
      ival = params_values['I_val']
      Y_X_N = params_values['Y']['X_N']
      
      
      
      LL = params_values['pH']['LL']  
      Iph = ca.exp((ival * ((w - UL) / (UL - LL))) ** 2)

      # Specific growth rate
      mu = (mu_max
            * (1 - ca.exp(-t / params_values['t_lag'])) 
            * (C / (C + params_values['k_C'])) 
            * (N / (N + params_values['k_N'])) 
            * (O / (O + params_values['k_O']))
            * (1 - (X / (Xmax))) 
            * Iph)

      ka7 = 10 ** (-params_values['pH']['pka7'])

      # Differential equations
      dXdt   = (mu- params_values['k_d']) * X                                                                   # Biomass
      dCdt   = - (mu / Y_X_C) * X                                                                               # Glycerol
      dNdt   = - (mu / Y_X_N) * X                                                                               # Ammonia
      dCO2dt = ((mu / params_values['Y']['X_CO2']) * X) - ka7 * (CO2 / (((10 ** -w) / ka7) + 1))                # CO2
      dOdt   = params_values['k_La'] * (params_values['O2_sat'] - O) - (mu / params_values['Y']['X_O2']) * X    # O2

      return ca.vertcat(dXdt, dCdt, dNdt, dCO2dt, dOdt)

# %% [markdown]
# # Ajuste de parametros

# %%
param_names = ['UL','Xmax'] # ,'mu_max','I_val','Y["X_C"]' , ,, 'Y["X_N"]'  
lb = [6, 1.0] #, 0.1, 3,0.1, , 20
ub = [8, 1.2] #, 1.0, 5,1.0, , 23

# %%
def simulate_model(p_vars, x0, params_values):
    # Symbolic variables
    t = ca.MX.sym('t')
    x = ca.MX.sym('x', 5)  # [X, C, N, CO2, O2]
    z = ca.MX.sym('z')     # [pH]

    # Systems's differential equations
    dxdt = DAE_system_CasADi_O2(t, x, z, p_vars, params_values)

    # Algebraic equation
    # Parameters
    ka1 = 10 ** (-params_values['pH']['pka1'])  # KH2PO4
    ka2 = 10 ** (-params_values['pH']['pka2'])  # C6H8O7
    ka3 = 10 ** (-params_values['pH']['pka3'])  # (C6H7O7)-
    ka4 = 10 ** (-params_values['pH']['pka4'])  # (C6H6O7)2-
    ka7 = 10 ** (-params_values['pH']['pka7'])  # CO2
    ka9 = 10 ** (-params_values['pH']['pka9'])  # H2O

    H = 10 ** (-z) 

    # Concentration of charges according to H+ ions
    KHPO4 = params_values['pH']['conc']['KH2PO4'] / ((H / ka1) + 1)
    C6H5O7 = params_values['pH']['conc']['C6H8O7'] / ((H ** 3 / (ka2 * ka3 * ka4)) + (H ** 2 / (ka3 * ka4)) + (H / ka4) + 1)
    C6H6O7 = (H / ka4) * C6H5O7
    C6H7O7 = (H / ka3) * C6H6O7
    HCO3 = x[3] / ((H / ka7) + 1)
    OH = ka9 / H

    f_z = OH + HCO3 + KHPO4 + (3 * C6H5O7) + (2 * C6H6O7) + C6H7O7 - params_values['pH']['alk'] - H
    f = ca.Function('f', [t, x, z], [dxdt])
    t_values = t_exp 
    
    dae = {'t': t, 'x': x, 'z': z, 'ode': f(t,x,z), 'alg': f_z}
    integrator = ca.integrator('integrator', 'idas', dae, {'grid': t_values, 'output_t0': True})

    
    sol_casadi = integrator(x0=x0[:-1], z0=x0[-1])
    return sol_casadi

# %%
X0 = X_exp[0]  
c0 = C_exp[0] 
n0 = N_exp[0] 
co20 = 0.439 / 1000
o20 = 0.0001
z0 = ph_exp[0]  
x0 = np.array([X0, c0, n0, co20, o20, z0])

# %% [markdown]
# # ajuste datos normales

# %%
def cost_function(p_vars):
    try:
        sol = simulate_model(p_vars,x0, params_values)

        
        x = sol['xf'].full().T
        z = sol['zf'].full().T
        X = x[:, 0]
        C = x[:, 1]
        N = x[:, 2]
        CO2 = x[:, 3]
        pH = z[:, 0]
        H = 10 ** (-pH)

        df_results = pd.DataFrame({
            'X': X,
            'C': C,
            'N': N,
            'CO2': CO2,
            'pH': pH,
            'H': H,
        })



        X_sim, C_sim, N_sim, CO2_sim, pH_sim = df_results['X'], df_results['C'], df_results['N'], df_results['CO2'], df_results['pH']

        err = np.sum((X_sim - X_exp)**2) + np.sum((C_sim - C_exp)**2) + np.sum((N_sim - N_exp)**2) + np.sum((pH_sim - ph_exp)**2)
        return [err]
    except:
        return [1e6]

# %%
problem = {
    "obj_func": cost_function,
    "bounds": FloatVar(lb=lb, ub=ub),
    "minmax": "min"
}

pso = PSO.OriginalPSO(epoch=200, pop_size=50, c1=2, c2=1.5, w=0.5)
start = time.perf_counter()
g_best = pso.solve(problem)
end = time.perf_counter()

print("Mejores parámetros encontrados:", g_best.solution)
print("Error mínimo:", g_best.target.fitness)
print(f"Tiempo de optimización: {end - start:.2f} s")

p_vars = g_best.solution
p_norm = p_vars
# Out:
# 2025/07/14 06:07:10 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: Solving single objective optimization problem.
# 2025/07/14 06:07:11 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 1, Current best: 0.830205637370984, Global best: 0.830205637370984, Runtime: 0.38279 seconds
# 2025/07/14 06:07:12 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 2, Current best: 0.7872640465159136, Global best: 0.7872640465159136, Runtime: 0.37737 seconds
# 2025/07/14 06:07:12 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 3, Current best: 0.7868089728611781, Global best: 0.7868089728611781, Runtime: 0.37342 seconds
# 2025/07/14 06:07:12 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 4, Current best: 0.7838072493088274, Global best: 0.7838072493088274, Runtime: 0.37773 seconds
# 2025/07/14 06:07:13 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 5, Current best: 0.7825194893613351, Global best: 0.7825194893613351, Runtime: 0.37527 seconds
# 2025/07/14 06:07:13 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 6, Current best: 0.7818694833979569, Global best: 0.7818694833979569, Runtime: 0.37659 seconds
# 2025/07/14 06:07:13 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 7, Current best: 0.7818694833979569, Global best: 0.7818694833979569, Runtime: 0.36863 seconds
# 2025/07/14 06:07:14 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 8, Current best: 0.7818694833979569, Global best: 0.7818694833979569, Runtime: 0.36498 seconds
# 2025/07/14 06:07:14 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 9, Current best: 0.7818629440577018, Global best: 0.7818629440577018, Runtime: 0.38431 seconds
# 2025/07/14 06:07:15 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 10, Current best: 0.7818629440577018, Global best: 0.7818629440577018, Runtime: 0.37788 seconds
# 2025/07/14 06:07:15 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 11, Current best: 0.7818629440577018, Global best: 0.7818629440577018, Runtime: 0.38449 seconds
# 2025/07/14 06:07:15 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 12, Current best: 0.7818629440577018, Global best: 0.7818629440577018, Runtime: 0.36442 seconds
# 2025/07/14 06:07:16 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 13, Current best: 0.7818582744108509, Global best: 0.7818582744108509, Runtime: 0.37674 seconds
# 2025/07/14 06:07:16 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 14, Current best: 0.7818577172260798, Global best: 0.7818577172260798, Runtime: 0.37997 seconds
# 2025/07/14 06:07:16 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 15, Current best: 0.781856823387352, Global best: 0.781856823387352, Runtime: 0.42377 seconds
# 2025/07/14 06:07:17 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 16, Current best: 0.781856823387352, Global best: 0.781856823387352, Runtime: 0.37151 seconds
# 2025/07/14 06:07:17 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 17, Current best: 0.781856823387352, Global best: 0.781856823387352, Runtime: 0.37784 seconds
# 2025/07/14 06:07:18 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 18, Current best: 0.7818567684166288, Global best: 0.7818567684166288, Runtime: 0.38536 seconds
# 2025/07/14 06:07:18 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 19, Current best: 0.7818567684166288, Global best: 0.7818567684166288, Runtime: 0.37326 seconds
# 2025/07/14 06:07:18 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 20, Current best: 0.7818567684166288, Global best: 0.7818567684166288, Runtime: 0.36453 seconds
# 2025/07/14 06:07:19 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 21, Current best: 0.7818567684166288, Global best: 0.7818567684166288, Runtime: 0.37094 seconds
# 2025/07/14 06:07:19 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 22, Current best: 0.7818567684166288, Global best: 0.7818567684166288, Runtime: 0.36664 seconds
# 2025/07/14 06:07:19 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 23, Current best: 0.7818567684166288, Global best: 0.7818567684166288, Runtime: 0.36934 seconds
# 2025/07/14 06:07:20 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 24, Current best: 0.7818567684166288, Global best: 0.7818567684166288, Runtime: 0.36337 seconds
# 2025/07/14 06:07:20 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 25, Current best: 0.7818567608134243, Global best: 0.7818567608134243, Runtime: 0.36493 seconds
# 2025/07/14 06:07:21 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 26, Current best: 0.7818567608134243, Global best: 0.7818567608134243, Runtime: 0.37213 seconds
# 2025/07/14 06:07:21 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 27, Current best: 0.7818567608134243, Global best: 0.7818567608134243, Runtime: 0.37256 seconds
# 2025/07/14 06:07:21 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 28, Current best: 0.7818567608134243, Global best: 0.7818567608134243, Runtime: 0.36496 seconds
# 2025/07/14 06:07:22 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 29, Current best: 0.7818567607336206, Global best: 0.7818567607336206, Runtime: 0.36928 seconds
# 2025/07/14 06:07:22 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 30, Current best: 0.7818567606550149, Global best: 0.7818567606550149, Runtime: 0.36488 seconds
# 2025/07/14 06:07:22 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 31, Current best: 0.7818567605338076, Global best: 0.7818567605338076, Runtime: 0.36498 seconds
# 2025/07/14 06:07:23 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 32, Current best: 0.781856760388411, Global best: 0.781856760388411, Runtime: 0.36063 seconds
# 2025/07/14 06:07:23 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 33, Current best: 0.7818567601194782, Global best: 0.7818567601194782, Runtime: 0.37091 seconds
# 2025/07/14 06:07:23 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 34, Current best: 0.7818567601194782, Global best: 0.7818567601194782, Runtime: 0.36614 seconds
# 2025/07/14 06:07:24 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 35, Current best: 0.7818567601194782, Global best: 0.7818567601194782, Runtime: 0.36953 seconds
# 2025/07/14 06:07:24 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 36, Current best: 0.7818567601194782, Global best: 0.7818567601194782, Runtime: 0.36267 seconds
# 2025/07/14 06:07:25 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 37, Current best: 0.7818567600845806, Global best: 0.7818567600845806, Runtime: 0.36726 seconds
# 2025/07/14 06:07:25 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 38, Current best: 0.7818567600845806, Global best: 0.7818567600845806, Runtime: 0.36521 seconds
# 2025/07/14 06:07:25 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 39, Current best: 0.7818567600845806, Global best: 0.7818567600845806, Runtime: 0.37131 seconds
# 2025/07/14 06:07:26 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 40, Current best: 0.7818567600789263, Global best: 0.7818567600789263, Runtime: 0.36677 seconds
# 2025/07/14 06:07:26 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 41, Current best: 0.7818567600789263, Global best: 0.7818567600789263, Runtime: 0.37030 seconds
# 2025/07/14 06:07:26 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 42, Current best: 0.7818567600789263, Global best: 0.7818567600789263, Runtime: 0.36529 seconds
# 2025/07/14 06:07:27 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 43, Current best: 0.7818567600789263, Global best: 0.7818567600789263, Runtime: 0.35946 seconds
# 2025/07/14 06:07:27 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 44, Current best: 0.7818567600789263, Global best: 0.7818567600789263, Runtime: 0.37125 seconds
# 2025/07/14 06:07:28 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 45, Current best: 0.7818567600478947, Global best: 0.7818567600478947, Runtime: 0.35851 seconds
# 2025/07/14 06:07:28 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 46, Current best: 0.7818567600478947, Global best: 0.7818567600478947, Runtime: 0.35846 seconds
# 2025/07/14 06:07:28 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 47, Current best: 0.7818567600474154, Global best: 0.7818567600474154, Runtime: 0.37021 seconds
# 2025/07/14 06:07:29 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 48, Current best: 0.781856760036459, Global best: 0.781856760036459, Runtime: 0.35972 seconds
# 2025/07/14 06:07:29 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 49, Current best: 0.781856760036459, Global best: 0.781856760036459, Runtime: 0.36554 seconds
# 2025/07/14 06:07:29 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 50, Current best: 0.781856760036459, Global best: 0.781856760036459, Runtime: 0.37293 seconds
# 2025/07/14 06:07:30 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 51, Current best: 0.781856760036459, Global best: 0.781856760036459, Runtime: 0.35962 seconds
# 2025/07/14 06:07:30 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 52, Current best: 0.781856760036459, Global best: 0.781856760036459, Runtime: 0.36478 seconds
# 2025/07/14 06:07:30 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 53, Current best: 0.781856760036459, Global best: 0.781856760036459, Runtime: 0.36456 seconds
# 2025/07/14 06:07:31 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 54, Current best: 0.781856760036459, Global best: 0.781856760036459, Runtime: 0.36027 seconds
# 2025/07/14 06:07:31 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 55, Current best: 0.781856760036459, Global best: 0.781856760036459, Runtime: 0.35894 seconds
# 2025/07/14 06:07:32 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 56, Current best: 0.781856760036459, Global best: 0.781856760036459, Runtime: 0.36096 seconds
# 2025/07/14 06:07:32 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 57, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.36702 seconds
# 2025/07/14 06:07:32 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 58, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.36643 seconds
# 2025/07/14 06:07:33 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 59, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.36619 seconds
# 2025/07/14 06:07:33 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 60, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.36237 seconds
# 2025/07/14 06:07:33 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 61, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.36420 seconds
# 2025/07/14 06:07:34 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 62, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.37421 seconds
# 2025/07/14 06:07:34 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 63, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.38689 seconds
# 2025/07/14 06:07:35 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 64, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.35980 seconds
# 2025/07/14 06:07:35 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 65, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.36505 seconds
# 2025/07/14 06:07:35 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 66, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.36413 seconds
# 2025/07/14 06:07:36 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 67, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.36007 seconds
# 2025/07/14 06:07:36 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 68, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.35583 seconds
# 2025/07/14 06:07:36 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 69, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.36083 seconds
# 2025/07/14 06:07:37 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 70, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.35932 seconds
# 2025/07/14 06:07:37 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 71, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.36061 seconds
# 2025/07/14 06:07:37 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 72, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.36078 seconds
# 2025/07/14 06:07:38 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 73, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.36606 seconds
# 2025/07/14 06:07:38 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 74, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.36236 seconds
# 2025/07/14 06:07:38 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 75, Current best: 0.781856759998534, Global best: 0.781856759998534, Runtime: 0.36152 seconds
# 2025/07/14 06:07:39 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 76, Current best: 0.7818567599759609, Global best: 0.7818567599759609, Runtime: 0.36346 seconds
# 2025/07/14 06:07:39 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 77, Current best: 0.7818567599759609, Global best: 0.7818567599759609, Runtime: 0.35975 seconds
# 2025/07/14 06:07:40 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 78, Current best: 0.7818567599759609, Global best: 0.7818567599759609, Runtime: 0.37134 seconds
# 2025/07/14 06:07:40 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 79, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35990 seconds
# 2025/07/14 06:07:40 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 80, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36449 seconds
# 2025/07/14 06:07:41 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 81, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36615 seconds
# 2025/07/14 06:07:41 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 82, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36988 seconds
# 2025/07/14 06:07:41 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 83, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36593 seconds
# 2025/07/14 06:07:42 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 84, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36649 seconds
# 2025/07/14 06:07:42 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 85, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36759 seconds
# 2025/07/14 06:07:43 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 86, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36484 seconds
# 2025/07/14 06:07:43 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 87, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36264 seconds
# 2025/07/14 06:07:43 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 88, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36164 seconds
# 2025/07/14 06:07:44 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 89, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35849 seconds
# 2025/07/14 06:07:44 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 90, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36331 seconds
# 2025/07/14 06:07:44 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 91, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36287 seconds
# 2025/07/14 06:07:45 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 92, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36216 seconds
# 2025/07/14 06:07:45 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 93, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35893 seconds
# 2025/07/14 06:07:45 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 94, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36467 seconds
# 2025/07/14 06:07:46 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 95, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36142 seconds
# 2025/07/14 06:07:46 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 96, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35977 seconds
# 2025/07/14 06:07:47 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 97, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36374 seconds
# 2025/07/14 06:07:47 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 98, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36049 seconds
# 2025/07/14 06:07:47 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 99, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36446 seconds
# 2025/07/14 06:07:48 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 100, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36780 seconds
# 2025/07/14 06:07:48 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 101, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35916 seconds
# 2025/07/14 06:07:48 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 102, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36528 seconds
# 2025/07/14 06:07:49 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 103, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36065 seconds
# 2025/07/14 06:07:49 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 104, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35684 seconds
# 2025/07/14 06:07:49 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 105, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.37057 seconds
# 2025/07/14 06:07:50 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 106, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35922 seconds
# 2025/07/14 06:07:50 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 107, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36282 seconds
# 2025/07/14 06:07:51 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 108, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36818 seconds
# 2025/07/14 06:07:51 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 109, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36213 seconds
# 2025/07/14 06:07:51 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 110, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36405 seconds
# 2025/07/14 06:07:52 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 111, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35688 seconds
# 2025/07/14 06:07:52 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 112, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36965 seconds
# 2025/07/14 06:07:52 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 113, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36443 seconds
# 2025/07/14 06:07:53 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 114, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36447 seconds
# 2025/07/14 06:07:53 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 115, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.37034 seconds
# 2025/07/14 06:07:53 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 116, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36279 seconds
# 2025/07/14 06:07:54 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 117, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35902 seconds
# 2025/07/14 06:07:54 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 118, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35906 seconds
# 2025/07/14 06:07:55 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 119, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35324 seconds
# 2025/07/14 06:07:55 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 120, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36233 seconds
# 2025/07/14 06:07:55 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 121, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36286 seconds
# 2025/07/14 06:07:56 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 122, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36464 seconds
# 2025/07/14 06:07:56 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 123, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.37308 seconds
# 2025/07/14 06:07:56 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 124, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36297 seconds
# 2025/07/14 06:07:57 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 125, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36010 seconds
# 2025/07/14 06:07:57 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 126, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35711 seconds
# 2025/07/14 06:07:57 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 127, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35662 seconds
# 2025/07/14 06:07:58 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 128, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36377 seconds
# 2025/07/14 06:07:58 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 129, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.37320 seconds
# 2025/07/14 06:07:59 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 130, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36045 seconds
# 2025/07/14 06:07:59 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 131, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35789 seconds
# 2025/07/14 06:07:59 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 132, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36179 seconds
# 2025/07/14 06:08:00 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 133, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35790 seconds
# 2025/07/14 06:08:00 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 134, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.37220 seconds
# 2025/07/14 06:08:00 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 135, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36947 seconds
# 2025/07/14 06:08:01 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 136, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36415 seconds
# 2025/07/14 06:08:01 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 137, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36247 seconds
# 2025/07/14 06:08:01 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 138, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36349 seconds
# 2025/07/14 06:08:02 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 139, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36188 seconds
# 2025/07/14 06:08:02 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 140, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35787 seconds
# 2025/07/14 06:08:03 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 141, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35949 seconds
# 2025/07/14 06:08:03 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 142, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36981 seconds
# 2025/07/14 06:08:03 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 143, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35991 seconds
# 2025/07/14 06:08:04 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 144, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36667 seconds
# 2025/07/14 06:08:04 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 145, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36214 seconds
# 2025/07/14 06:08:04 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 146, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36240 seconds
# 2025/07/14 06:08:05 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 147, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35012 seconds
# 2025/07/14 06:08:05 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 148, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35749 seconds
# 2025/07/14 06:08:05 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 149, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.37115 seconds
# 2025/07/14 06:08:06 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 150, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36847 seconds
# 2025/07/14 06:08:06 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 151, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36328 seconds
# 2025/07/14 06:08:07 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 152, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36142 seconds
# 2025/07/14 06:08:07 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 153, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36148 seconds
# 2025/07/14 06:08:07 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 154, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36611 seconds
# 2025/07/14 06:08:08 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 155, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36122 seconds
# 2025/07/14 06:08:08 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 156, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36508 seconds
# 2025/07/14 06:08:08 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 157, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36473 seconds
# 2025/07/14 06:08:09 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 158, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36240 seconds
# 2025/07/14 06:08:09 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 159, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35972 seconds
# 2025/07/14 06:08:09 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 160, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35912 seconds
# 2025/07/14 06:08:10 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 161, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36449 seconds
# 2025/07/14 06:08:10 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 162, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36357 seconds
# 2025/07/14 06:08:11 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 163, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.37153 seconds
# 2025/07/14 06:08:11 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 164, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36667 seconds
# 2025/07/14 06:08:11 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 165, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36616 seconds
# 2025/07/14 06:08:12 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 166, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36136 seconds
# 2025/07/14 06:08:12 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 167, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36396 seconds
# 2025/07/14 06:08:12 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 168, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.37250 seconds
# 2025/07/14 06:08:13 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 169, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.38321 seconds
# 2025/07/14 06:08:13 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 170, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.38036 seconds
# 2025/07/14 06:08:14 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 171, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36128 seconds
# 2025/07/14 06:08:14 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 172, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36336 seconds
# 2025/07/14 06:08:14 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 173, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36113 seconds
# 2025/07/14 06:08:15 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 174, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36598 seconds
# 2025/07/14 06:08:15 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 175, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35604 seconds
# 2025/07/14 06:08:15 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 176, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36533 seconds
# 2025/07/14 06:08:16 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 177, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35997 seconds
# 2025/07/14 06:08:16 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 178, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36284 seconds
# 2025/07/14 06:08:16 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 179, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36654 seconds
# 2025/07/14 06:08:17 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 180, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.37371 seconds
# 2025/07/14 06:08:17 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 181, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36331 seconds
# 2025/07/14 06:08:18 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 182, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36031 seconds
# 2025/07/14 06:08:18 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 183, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36668 seconds
# 2025/07/14 06:08:18 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 184, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36422 seconds
# 2025/07/14 06:08:19 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 185, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36450 seconds
# 2025/07/14 06:08:19 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 186, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36254 seconds
# 2025/07/14 06:08:19 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 187, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36680 seconds
# 2025/07/14 06:08:20 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 188, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36171 seconds
# 2025/07/14 06:08:20 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 189, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36095 seconds
# 2025/07/14 06:08:20 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 190, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36559 seconds
# 2025/07/14 06:08:21 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 191, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35937 seconds
# 2025/07/14 06:08:21 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 192, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36724 seconds
# 2025/07/14 06:08:22 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 193, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35830 seconds
# 2025/07/14 06:08:22 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 194, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35994 seconds
# 2025/07/14 06:08:22 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 195, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36148 seconds
# 2025/07/14 06:08:23 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 196, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35469 seconds
# 2025/07/14 06:08:23 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 197, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35191 seconds
# 2025/07/14 06:08:23 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 198, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.36220 seconds
# 2025/07/14 06:08:24 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 199, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35655 seconds
# 2025/07/14 06:08:24 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 200, Current best: 0.7818567599326791, Global best: 0.7818567599326791, Runtime: 0.35722 seconds
# Mejores parámetros encontrados: [7.5710168 1.1743136]
# Error mínimo: 0.7818567599326791
# Tiempo de optimización: 73.76 s

# %%
sol = simulate_model(p_norm, x0, params_values)
sol1 = simulate_model(P_og, x0, params_values)

best_sim = sol['xf'].full().T 
solz = sol['zf'].full().T  
best_sim1 = sol1['xf'].full().T  
solz1 = sol1['zf'].full().T  

colors = {
    'X': '#66C2A6',
    'C': '#FD8D62',
    'N': '#8DA0CB',
    'CO2': '#FED92F',
    'O2': '#A7D854',
    'pH': '#E78AC3',
    'mu': '#B3B3B3'
}

def darken_color(color, factor=0.6):
    rgb = mcolors.to_rgb(color)
    return tuple(factor * c for c in rgb)

fig, axes = plt.subplots(4, 1, figsize=(8, 14))


axes[0].scatter(t_exp, X_exp, marker='o', label="Biomass exp",color=colors['X'])
axes[0].plot(t_exp, best_sim[:, 0], '-', label="Biomass sim",color=colors['X'])
axes[0].plot(t_exp, best_sim1[:, 0], '--', label="Biomass sim (original)",color=darken_color(colors['X']))
axes[0].set_xlabel("Time (h)")
axes[0].set_ylabel("Concentration")
axes[0].set_title("Model adjustment with PSO")
axes[0].legend()
axes[0].grid(True)



axes[1].scatter(t_exp, C_exp, marker='o', label="Glycerol exp",color=colors['C'])
axes[1].plot(t_exp, best_sim[:, 1], '-', label="Glycerol sim",color=colors['C'])
axes[1].plot(t_exp, best_sim1[:, 1], '--', label="Glycerol sim (original)",color=darken_color(colors['C']))
axes[1].set_xlabel("Time (h)")
axes[1].set_ylabel("concentration")
axes[1].set_title("Model adjustment with PSO")
axes[1].legend()
axes[1].grid(True)



axes[2].scatter(t_exp, N_exp,marker= 'o', label="Ammonia exp",color=colors['N'])
axes[2].plot(t_exp, best_sim[:, 2], '-', label="Ammonia sim",color=colors['N'])
axes[2].plot(t_exp, best_sim1[:, 2], '--', label="Ammonia sim (original)",color=darken_color(colors['N']))
axes[2].set_xlabel("Time (h)")
axes[2].set_ylabel("concentration")
axes[2].set_title("Model adjustment with PSO")
axes[2].legend()
axes[2].grid(True)



axes[3].scatter(t_exp, ph_exp, marker='o', label="PH exp",color=colors['pH'])
axes[3].plot(t_exp, solz[:, 0], '-', label="PH sim",color=colors['pH'])
axes[3].plot(t_exp, solz1[:, 0], '--', label="PH sim (original)",color=darken_color(colors['pH']))
axes[3].set_xlabel("Time (h)")
axes[3].set_ylabel("Concentration")
axes[3].set_title("Model adjustment with PSO")
axes[3].legend()
axes[3].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Comparación de parametros

# %%
df_params = pd.DataFrame({
    "Parámetro": param_names,
    "p_og": P_og,
    "p_norm": p_norm
})

df_params
# Out:
#   Parámetro    p_og    p_norm
# 0        UL  7.4000  7.571017
# 1      Xmax  1.4462  1.174314

# %% [markdown]
# # validacion

# %%
df_exp_v = pd.read_excel('Experimental_data.xlsx', sheet_name='Validation Data')
t_exp = df_exp_v['Time (hours)']
X_exp_v = df_exp_v['Biomass (g/L)']
C_exp_v = df_exp_v['Glycerol (g/L)']
N_exp_v = df_exp_v['Ammonia (g/L)']
ph_exp_v = df_exp_v['pH']

X_err = df_exp_v.iloc[:, 2]
C_err = df_exp_v.iloc[:, 4]
N_err = df_exp_v.iloc[:, 6]
ph_err = df_exp_v.iloc[:, 8]

# %%
X0 = X_exp_v[0]
c0 = C_exp_v[0]
n0 = N_exp_v[0]
co20 = 0.439 / 1000
o20 = 0.0001
z0 = ph_exp[0]  
x0 = np.array([X0, c0, n0, co20, o20, z0])

# %%
sol = simulate_model(p_norm, x0, params_values)
sol1 = simulate_model(P_og, x0, params_values)

best_sim = sol['xf'].full().T  
solz = sol['zf'].full().T  
best_sim1 = sol1['xf'].full().T  
solz1 = sol1['zf'].full().T  

colors = {
    'X': '#66C2A6',
    'C': '#FD8D62',
    'N': '#8DA0CB',
    'CO2': '#FED92F',
    'O2': '#A7D854',
    'pH': '#E78AC3',
    'mu': '#B3B3B3'
}

def darken_color(color, factor=0.6):
    rgb = mcolors.to_rgb(color)
    return tuple(factor * c for c in rgb)

fig, axes = plt.subplots(4, 1, figsize=(8, 10))

t_casadi_O2 = np.linspace(0, 80, 501)
# Biomass
axes[0].plot(t_exp, best_sim[:, 0], label='New', color=colors['X'])
axes[0].plot(t_exp, best_sim1[:, 0] ,'--',label='Original', color=colors['X'])
axes[0].scatter(t_exp, X_exp_v, label='Validation', color=darken_color(colors['X']), marker='o')
axes[0].set_title('Biomass (X)')
axes[0].set_xlabel('Time (h)')
axes[0].set_ylabel('X (g/L)')
axes[0].grid(True)
axes[0].legend()

# Glycerol
axes[1].plot(t_exp, best_sim[:, 1], label='new', color=colors['C'])
axes[1].plot(t_exp, best_sim1[:, 1] ,'--',label='Original', color=colors['C'])
axes[1].scatter(t_exp, C_exp_v, label='Validation', color=darken_color(colors['C']), marker='o')
axes[1].set_title('Glycerol (C)')
axes[1].set_xlabel('Time (h)')
axes[1].set_ylabel('C (g/L)')
axes[1].grid(True)
axes[1].legend()

# Ammonia
axes[2].plot(t_exp, best_sim[:, 2], label='New', color=colors['N'])
axes[2].plot(t_exp, best_sim1[:, 2] ,'--',label='Original', color=colors['N'])
axes[2].scatter(t_exp, N_exp_v, label='Validation', color=darken_color(colors['N']), marker='o')
axes[2].set_title('Ammonia (N)')
axes[2].set_xlabel('Time (h)')
axes[2].set_ylabel('N (g/L)')
axes[2].grid(True)
axes[2].legend()

# pH
axes[3].plot(t_exp, solz[:, 0], label='New', color=colors['pH'])
axes[3].plot(t_exp, solz1[:, 0] ,'--',label='Original', color=colors['pH'])
axes[3].scatter(t_exp, ph_exp_v, label='Validation', color=darken_color(colors['pH']), marker='o')
axes[3].set_title('pH')
axes[3].set_xlabel('Time (h)')
axes[3].set_ylabel('pH')
axes[3].grid(True)
axes[3].legend()

fig.suptitle('Model Prediction vs Validation Data, 4 parameter set', fontsize=16)
plt.tight_layout()
plt.show()

# %%
import numpy as np


X_exp = X_exp_v    
C_exp = C_exp_v
N_exp = N_exp_v
pH_exp = ph_exp_v


X_sim = best_sim[:, 0]
C_sim = best_sim[:, 1]
N_sim = best_sim[:, 2]
pH_sim = solz[:, 0]


y_exp = np.concatenate([X_exp, C_exp, N_exp, pH_exp])
y_sim = np.concatenate([X_sim, C_sim, N_sim, pH_sim])
y_sim_og = np.concatenate([best_sim1[:, 0], best_sim1[:, 1], best_sim1[:, 2], solz1[:, 0]])



n = len(y_exp)
k = len(param_names)  

NMRSE_norm = []
def rmse(y_true, y_pred):
    return np.sqrt(np.mean((y_true - y_pred)**2))

def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def nrmse(y_true, y_pred):
    return rmse(y_true, y_pred) / (np.max(y_true) - np.min(y_true))  

#RMSE, MAPE y NRMSE por variable
print("\nMétricas por variable (nuevo modelo):")
for label, y_e, y_s in zip(['X', 'C', 'N', 'pH'], [X_exp, C_exp, N_exp, pH_exp], [X_sim, C_sim, N_sim, pH_sim]):
    print(f"{label}:")
    print(f"  RMSE:   {rmse(y_e, y_s):.4f}")
    print(f"  NRMSE:  {nrmse(y_e, y_s):.4f}")
    print(f"  MAPE:   {mape(y_e, y_s):.2f} %")
    NMRSE_norm.append(nrmse(y_e, y_s))


#RMSE, MAPE y NRMSE por variable (modelo original)
print("\nMétricas por variable (modelo original):")
for label, y_e, y_s in zip(['X', 'C', 'N', 'pH'], [X_exp, C_exp, N_exp, pH_exp], 
                                        [best_sim1[:, 0], best_sim1[:, 1], best_sim1[:, 2], solz1[:, 0]]):
    print(f"{label}:")
    print(f"  RMSE:   {rmse(y_e, y_s):.4f}")
    print(f"  NRMSE:  {nrmse(y_e, y_s):.4f}")
    print(f"  MAPE:   {mape(y_e, y_s):.2f} %")

#Métricas globales
rss = np.sum((y_exp - y_sim)**2)
rss_og = np.sum((y_exp - y_sim_og)**2)

aic_new = 2 * k + n * np.log(rss / n)
bic_new = k * np.log(n) + n * np.log(rss / n)

aic_og = 2 * k + n * np.log(rss_og / n)
bic_og = k * np.log(n) + n * np.log(rss_og / n)

print("\nMétricas globales:")
print(f"AIC (nuevo modelo): {aic_new:.2f}")
print(f"BIC (nuevo modelo): {bic_new:.2f}")
print(f"AIC (modelo original): {aic_og:.2f}")
print(f"BIC (modelo original): {bic_og:.2f}")
print(f"RMSE (nuevo modelo): {rmse(y_exp, y_sim):.4f}")
print(f"RMSE (modelo original): {rmse(y_exp, y_sim_og):.4f}")
print(f"NMRSE (nuevo modelo): {nrmse(y_exp, y_sim):.4f}")
print(f"NMRSE (modelo original): {nrmse(y_exp, y_sim_og):.4f}")
print(f"MAPE (nuevo modelo): {mape(y_exp, y_sim):.2f} %")
print(f"MAPE (modelo original): {mape(y_exp, y_sim_og):.2f} %")
# Out:
# Métricas por variable (nuevo modelo):
# X:
#   RMSE:   0.1935
#   NRMSE:  0.1973
#   MAPE:   18.70 %
# C:
#   RMSE:   0.4258
#   NRMSE:  0.1595
#   MAPE:   7.05 %
# N:
#   RMSE:   0.0475
#   NRMSE:  0.2868
#   MAPE:   4.18 %
# pH:
#   RMSE:   0.0942
#   NRMSE:  0.1177
#   MAPE:   0.88 %
#
# Métricas por variable (modelo original):
# X:
#   RMSE:   0.3441
#   NRMSE:  0.3507
#   MAPE:   35.18 %
# C:
#   RMSE:   0.6909
#   NRMSE:  0.2589
#   MAPE:   13.51 %
# N:
#   RMSE:   0.0445
#   NRMSE:  0.2685
#   MAPE:   3.50 %
# pH:
#   RMSE:   0.1319
#   NRMSE:  0.1648
#   MAPE:   1.58 %
#
# Métricas globales:
# AIC (nuevo modelo): -110.26
# BIC (nuevo modelo): -106.88
# AIC (modelo original): -70.89
# BIC (modelo original): -67.51
# RMSE (nuevo modelo): 0.2397
# RMSE (modelo original): 0.3922
# NMRSE (nuevo modelo): 0.0344
# NMRSE (modelo original): 0.0563
# MAPE (nuevo modelo): 7.70 %
# MAPE (modelo original): 13.44 %

# %% [markdown]
# # comparacion de modelos

# %% [markdown]
# ## modelo hipoxia ajsutado

# %%
# Original parameters
params_og = {
      't_lag': 7,
      'k_C': 0.3828,
      'k_N': 1.0027e-4, 
      'Y': {'X_C': 0.484,
      'X_N': 21.575, 
      'X_CO2': 0.3687}, 
      'Xmax': 1.4462,
      'mu_max': 0.19,
      'k_d': 0.001, 
      'pH': {'pka1': 6.86, # pKa of KH2PO4
            'pka2': 3.13,  # pka of C6H8O7
            'pka3': 4.76,  # pka of (C6H7O7)-
            'pka4': 6.40,  # pka of (C6H6O7)2-
            'pka5': 9.25,  # pka of NH3
            'pka6': 14.15, # pka of C3H8O3
            'pka7': 6.35,  # pka of CO2
            'pka8': 10.33, # pka of (HCO3)-
            'pka9': 14,    # pka of H2O
            'conc': {'KH2PO4': 2.18,
                  'C6H8O7': 2},
            'LL': 3.4687,
            'UL': 7.4,
            'alk': 7.2},
      'I_val': 4.0413,
      'pH_M': [0, 14]} 

# Parameters for saturated oxygen
params_oxygen = copy.deepcopy(params_og)
params_oxygen['Y']['X_O2'] = 1.352
params_oxygen['O2_sat'] = 0.007267
params_oxygen['k_La'] = 86.26
params_oxygen['k_O'] = 0.0045  

# Parameters for hypoxia
params_hypoxia = copy.deepcopy(params_og)
params_hypoxia['Y']['X_O2'] = 1.352
params_hypoxia['O2_sat'] = 0.007267
params_hypoxia['k_La'] = 5
params_hypoxia['k_O'] = 0.0045

# %%
# Experimental data

df_exp_v = pd.read_excel('Experimental_data.xlsx', sheet_name='Validation Data')
t_exp = df_exp_v['Time (hours)']
t_exp_v = df_exp_v['Time (hours)']
X_exp_v = df_exp_v['Biomass (g/L)']
C_exp_v = df_exp_v['Glycerol (g/L)']
N_exp_v = df_exp_v['Ammonia (g/L)']
ph_exp_v = df_exp_v['pH']


# Initial conditions
X0 = X_exp_v[0]
c0 = C_exp_v[0]
n0 = N_exp_v[0]
co20 = 0.439 / 1000
o20 = 0.0001
z0 = ph_exp[0]  
x0 = np.array([X0, c0, n0, co20, o20, z0])

t_exp = np.linspace(0, 100, 501)
sol = simulate_model(p_norm, x0, params_values)

best_sim = sol['xf'].full().T  
solz = sol['zf'].full().T 

mu_values_casadi_adjusted = np.zeros_like(best_sim[:, 4])
for i in range(len(best_sim[:, 1])):
    mu_values_casadi_adjusted[i] = (
        p_norm[1] *
        (1 - np.exp(-t_exp[i] / params_values['t_lag'])) *
        (best_sim[:, 1][i] / (best_sim[:, 1][i] + params_values['k_C'])) *
        (best_sim[:, 2][i] / (best_sim[:, 2][i] + params_values['k_N'])) *
        (best_sim[:, 4][i] / (best_sim[:, 4][i] + params_values['k_O'])) *
        np.exp((params_og['I_val'] *
               (solz[:, 0][i] - p_norm[0]) /
               (p_norm[0] - params_og['pH']['LL'])) ** 2) *
        (1 - best_sim[:, 0][i] / p_norm[1])
    )

# %% [markdown]
# ## OG model

# %%
def DAE_system_CasADi_OG(t, vars, z_algebraic, params):

    # Unpack variables
    X, C, N, CO2 = vars[0], vars[1], vars[2], vars[3]
    w = z_algebraic[0] # pH

    # Explicit algebraic equations
    # pH inhibition factor
    Iph = ca.exp((params['I_val'] * ((w - params['pH']['UL']) / (params['pH']['UL'] - params['pH']['LL']))) ** 2)

    # Specific growth rate
    mu = (params['mu_max'] 
          * (1 - ca.exp(-t / params['t_lag'])) 
          * (C / (C + params['k_C'])) 
          * (N / (N + params['k_N'])) 
          * (1 - (X / (params['Xmax']))) 
          * Iph)
    
    ka7 = 10 ** (-params['pH']['pka7'])
    
    # Differential equations
    dXdt   = (mu- params['k_d']) * X                                                     # Biomass
    dCdt   = - (mu / params['Y']['X_C']) * X                                             # Glycerol
    dNdt   = - (mu / params['Y']['X_N']) * X                                             # Ammonia
    dCO2dt = ((mu / params['Y']['X_CO2']) * X) - ka7 * (CO2 / (((10 ** -w) / ka7) + 1))  # CO2

    return ca.vertcat(dXdt, dCdt, dNdt, dCO2dt)

# %%
# Symbolic variables
t = ca.MX.sym('t')
x = ca.MX.sym('x', 4)  # [X, C, N, CO2]
z = ca.MX.sym('z')     # [pH]

# Systems's differential equations
dxdt = DAE_system_CasADi_OG(t, x, z, params_og)

# Algebraic equation
# Parameters
ka1 = 10 ** (-params_oxygen['pH']['pka1'])  # KH2PO4
ka2 = 10 ** (-params_oxygen['pH']['pka2'])  # C6H8O7
ka3 = 10 ** (-params_oxygen['pH']['pka3'])  # (C6H7O7)-
ka4 = 10 ** (-params_oxygen['pH']['pka4'])  # (C6H6O7)2-
ka7 = 10 ** (-params_oxygen['pH']['pka7'])  # CO2
ka9 = 10 ** (-params_oxygen['pH']['pka9'])  # H2O

H = 10 ** (-z) 

# Concentration of charges according to H+ ions
KHPO4 = params_oxygen['pH']['conc']['KH2PO4'] / ((H / ka1) + 1)
C6H5O7 = params_oxygen['pH']['conc']['C6H8O7'] / ((H ** 3 / (ka2 * ka3 * ka4)) + (H ** 2 / (ka3 * ka4)) + (H / ka4) + 1)
C6H6O7 = (H / ka4) * C6H5O7
C6H7O7 = (H / ka3) * C6H6O7
HCO3 = x[3] / ((H / ka7) + 1)
OH = ka9 / H

f_z = OH + HCO3 + KHPO4 + (3 * C6H5O7) + (2 * C6H6O7) + C6H7O7 - params_oxygen['pH']['alk'] - H

# CasADi function
f = ca.Function('f', [t, x, z], [dxdt])

# %%
# Initial conditions
X0 = 0.223
c0 = 5.922
n0 = 1.027
co20 = 0.439 / 1000
x0 = np.array([X0, c0, n0, co20])

z0 = np.array([0.0])  


tf = 100
n_steps = 500

t_values = np.linspace(0, tf, n_steps + 1)

# ODE system
dae = {'t': t, 'x': x, 'z': z, 'ode': f(t, x, z), 'alg': f_z}
integrator = ca.integrator('integrator', 'idas', dae, {'grid': t_values, 'output_t0': True})

# Solve
sol_casadi_OG = integrator(x0=x0, z0=z0)

# %%
# Extract results
t_casadi_og = np.linspace(0, 100, 501)
x_final_og = sol_casadi_OG['xf'].full().T
z_final_og = sol_casadi_OG['zf'].full().T

X_casadi_og = x_final_og[:, 0]
C_casadi_og = x_final_og[:, 1]
N_casadi_og = x_final_og[:, 2]
CO2_casadi_og = x_final_og[:, 3]
pH_casadi_og = z_final_og[:, 0]

# Compute specific growth rate over time
mu_values_casadi_og = np.zeros_like(C_casadi_og)
for i in range(len(C_casadi_og)):
    mu_values_casadi_og[i] = (
        params_og['mu_max'] *
        (1 - np.exp(-t_casadi_og[i] / params_og['t_lag'])) *
        (C_casadi_og[i] / (C_casadi_og[i] + params_og['k_C'])) *
        (N_casadi_og[i] / (N_casadi_og[i] + params_og['k_N'])) *
        np.exp((params_og['I_val'] *
               (pH_casadi_og[i] - params_og['pH']['UL']) /
               (params_og['pH']['UL'] - params_og['pH']['LL'])) ** 2) *
        (1 - X_casadi_og[i] / params_og['Xmax'])
    )

# %% [markdown]
# ## modelo hipoxia parametros anteriores

# %%
def DAE_system_CasADi_O2(t, vars, z_algebraic, params):

    # Unpack variables
    X, C, N, CO2, O = vars[0], vars[1], vars[2], vars[3], vars[4]
    w = z_algebraic[0] # pH

    # Explicit algebraic equations
    # pH inhibition factor
    Iph = ca.exp((params['I_val'] * ((w - params['pH']['UL']) / (params['pH']['UL'] - params['pH']['LL']))) ** 2)

    # Specific growth rate
    mu = (params['mu_max'] 
          * (1 - ca.exp(-t / params['t_lag'])) 
          * (C / (C + params['k_C'])) 
          * (N / (N + params['k_N'])) 
          * (O / (O + params['k_O']))
          * (1 - (X / (params['Xmax']))) 
          * Iph)
    
    ka7 = 10 ** (-params['pH']['pka7'])
    
    # Differential equations
    dXdt   = (mu- params['k_d']) * X                                                     # Biomass
    dCdt   = - (mu / params['Y']['X_C']) * X                                             # Glycerol
    dNdt   = - (mu / params['Y']['X_N']) * X                                             # Ammonia
    dCO2dt = ((mu / params['Y']['X_CO2']) * X) - ka7 * (CO2 / (((10 ** -w) / ka7) + 1))  # CO2
    dOdt   = params['k_La'] * (params['O2_sat'] - O) - (mu / params['Y']['X_O2']) * X    # O2

    return ca.vertcat(dXdt, dCdt, dNdt, dCO2dt, dOdt)

# %%
# Symbolic variables
t = ca.MX.sym('t')
x = ca.MX.sym('x', 5)  # [X, C, N, CO2, O2]
z = ca.MX.sym('z')     # [pH]

# Systems's differential equations
dxdt = DAE_system_CasADi_O2(t, x, z, params_oxygen)

# Algebraic equation
# Parameters
ka1 = 10 ** (-params_oxygen['pH']['pka1'])  # KH2PO4
ka2 = 10 ** (-params_oxygen['pH']['pka2'])  # C6H8O7
ka3 = 10 ** (-params_oxygen['pH']['pka3'])  # (C6H7O7)-
ka4 = 10 ** (-params_oxygen['pH']['pka4'])  # (C6H6O7)2-
ka7 = 10 ** (-params_oxygen['pH']['pka7'])  # CO2
ka9 = 10 ** (-params_oxygen['pH']['pka9'])  # H2O

H = 10 ** (-z) 

# Concentration of charges according to H+ ions
KHPO4 = params_oxygen['pH']['conc']['KH2PO4'] / ((H / ka1) + 1)
C6H5O7 = params_oxygen['pH']['conc']['C6H8O7'] / ((H ** 3 / (ka2 * ka3 * ka4)) + (H ** 2 / (ka3 * ka4)) + (H / ka4) + 1)
C6H6O7 = (H / ka4) * C6H5O7
C6H7O7 = (H / ka3) * C6H6O7
HCO3 = x[3] / ((H / ka7) + 1)
OH = ka9 / H

f_z = OH + HCO3 + KHPO4 + (3 * C6H5O7) + (2 * C6H6O7) + C6H7O7 - params_oxygen['pH']['alk'] - H

# CasADi function
f_O2 = ca.Function('f', [t, x, z], [dxdt])

# %%
# Initial conditions
X0 = 0.223
c0 = 5.922
n0 = 1.027
co20 = 0.439 / 1000
o20 = 0.0001
x0 = np.array([X0, c0, n0, co20, o20])

z0 = np.array([0.0])  # Initial guess for pH

# Final time and number of integration steps
tf = 100
n_steps = 500

# Simulation time vector
t_values = np.linspace(0, tf, n_steps + 1)

# ODE system
dae = {'t': t, 'x': x, 'z': z, 'ode': f_O2(t,x,z), 'alg': f_z}
integrator_O2 = ca.integrator('integrator', 'idas', dae, {'grid': t_values, 'output_t0': True})

# Solve
sol_casadi_O2 = integrator_O2(x0=x0, z0=z0)

# %%
# Extract results
t_casadi_O2 = np.linspace(0, 100, 501)
x_final_O2 = sol_casadi_O2['xf'].full().T
z_final_O2 = sol_casadi_O2['zf'].full().T

X_casadi_O2 = x_final_O2[:, 0]
C_casadi_O2 = x_final_O2[:, 1]
N_casadi_O2 = x_final_O2[:, 2]
CO2_casadi_O2 = x_final_O2[:, 3]
O2_casadi_O2 = x_final_O2[:, 4]
pH_casadi_O2 = z_final_O2[:, 0]

# Compute specific growth rate over time
mu_values_casadi_O2 = np.zeros_like(C_casadi_O2)
for i in range(len(C_casadi_O2)):
    mu_values_casadi_O2[i] = (
        params_oxygen['mu_max'] *
        (1 - np.exp(-t_casadi_O2[i] / params_oxygen['t_lag'])) *
        (C_casadi_O2[i] / (C_casadi_O2[i] + params_oxygen['k_C'])) *
        (N_casadi_O2[i] / (N_casadi_O2[i] + params_oxygen['k_N'])) *
        (O2_casadi_O2[i] / (O2_casadi_O2[i] + params_oxygen['k_O'])) *
        np.exp((params_oxygen['I_val'] *
               ((pH_casadi_O2[i] - params_oxygen['pH']['UL']) /
               (params_oxygen['pH']['UL'] - params_oxygen['pH']['LL']))) ** 2) *
        (1 - X_casadi_O2[i] / params_oxygen['Xmax'])
    )

# %% [markdown]
# ## Original Model vs O2 Models

# %%
colors = {
    'X': '#66C2A6',
    'C': '#FD8D62',
    'N': '#8DA0CB',
    'CO2': '#FED92F',
    'O2': '#A7D854',
    'pH': '#E78AC3',
    'mu': '#B3B3B3'
}

def darken_color(color, factor=0.6):
    rgb = mcolors.to_rgb(color)
    return tuple(factor * c for c in rgb)

fig, axes = plt.subplots(7, 1, figsize=(8, 14))

axes[0].plot(t_casadi_og, X_casadi_og, label='X base', color=colors['X'])
axes[0].plot(t_casadi_O2, X_casadi_O2, '--', label='X O2', color=darken_color(colors['X']))
axes[0].plot(t_exp, best_sim[:, 0],'-.', label='X O2 Adjusted', color=colors['X'])
axes[0].scatter(t_exp_v, X_exp_v, label='Validation', color=darken_color(colors['X']), marker='.')
axes[0].errorbar(t_exp_v, X_exp_v, yerr=X_err, fmt='.', color=darken_color(colors['X']), markersize=2, capsize=3)
axes[0].set_title('Biomass (X)')
axes[0].set_xlabel('Time (h)')
axes[0].set_ylabel('X (g/L)')
axes[0].grid(True)
axes[0].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[1].plot(t_casadi_og, C_casadi_og, label='C base', color=colors['C'])
axes[1].plot(t_casadi_O2, C_casadi_O2, '--', label='C O2', color=darken_color(colors['C']))
axes[1].plot(t_exp, best_sim[:, 1],'-.', label='C O2 Adjusted', color=colors['C'])
axes[1].scatter(t_exp_v, C_exp_v, label='Validation', color=darken_color(colors['C']), marker='.')
axes[1].errorbar(t_exp_v, C_exp_v, yerr=C_err, fmt='.', color=darken_color(colors['C']), markersize=2, capsize=3)
axes[1].set_title('Glycerol (C)')
axes[1].set_xlabel('Time (h)')
axes[1].set_ylabel('C (g/L)')
axes[1].grid(True)
axes[1].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[2].plot(t_casadi_og, N_casadi_og, label='N base', color=colors['N'])
axes[2].plot(t_casadi_O2, N_casadi_O2, '--', label='N O2', color=darken_color(colors['N']))
axes[2].plot(t_exp, best_sim[:, 2],'-.', label='N O2 Adjusted', color=colors['N'])
axes[2].scatter(t_exp_v, N_exp_v, label='Validation', color=darken_color(colors['N']), marker='.')
axes[2].errorbar(t_exp_v, N_exp_v, yerr=N_err, fmt='.', color=darken_color(colors['N']), markersize=2, capsize=3)
axes[2].set_title('Ammonia (N)')
axes[2].set_xlabel('Time (h)')
axes[2].set_ylabel('N (g/L)')
axes[2].grid(True)
axes[2].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[4].plot(t_casadi_og, CO2_casadi_og, label='CO2 base', color=colors['CO2'])
axes[4].plot(t_casadi_O2, CO2_casadi_O2, '--', label='CO2 O2', color=darken_color(colors['CO2']))
axes[4].plot(t_exp, best_sim[:, 3],'-.', label='CO2 O2 Adjusted', color=colors['CO2'])
axes[4].set_title('Carbon Dioxide (CO2)')
axes[4].set_xlabel('Time (h)')
axes[4].set_ylabel('CO2 (g/L)')
axes[4].grid(True)
axes[4].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[5].plot(t_casadi_O2, O2_casadi_O2, '--', label='O2 O2', color=darken_color(colors['O2']))
axes[5].plot(t_exp[1:], best_sim[1:,4],'-.', label='O2 O2 Adjusted', color=colors['O2'])
axes[5].set_title('Dissolved Oxygen (O2)')
axes[5].set_xlabel('Time (h)')
axes[5].set_ylabel('O2 (g/L)')
axes[5].grid(True)
axes[5].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[3].plot(t_casadi_og, pH_casadi_og, label='pH base', color=colors['pH'])
axes[3].plot(t_casadi_O2, pH_casadi_O2, '--', label='pH O2', color=darken_color(colors['pH']))
axes[3].plot(t_exp, solz[:, 0],'-.', label='pH O2 Adjusted', color=colors['pH'])
axes[3].scatter(t_exp_v, ph_exp_v, label='Validation', color=darken_color(colors['pH']), marker='.')
axes[3].errorbar(t_exp_v, ph_exp_v, yerr=ph_err, fmt='.', color=darken_color(colors['pH']), markersize=2, capsize=3)
axes[3].set_title('pH')
axes[3].set_xlabel('Time (h)')
axes[3].set_ylabel('pH')
axes[3].grid(True)
axes[3].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[6].plot(t_casadi_og, mu_values_casadi_og, label='μ base', color=colors['mu'])
axes[6].plot(t_casadi_O2, mu_values_casadi_O2, '--', label='μ O2', color=darken_color(colors['mu']))
axes[6].plot(t_exp, mu_values_casadi_adjusted, '-.', label='μ O2 Adjusted', color=(colors['mu']))
axes[6].set_title('Specific Growth Rate (μ)')
axes[6].set_xlabel('Time (h)')
axes[6].set_ylabel('μ (1/h)')
axes[6].grid(True)
axes[6].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

#fig.suptitle('Comparison between models', fontsize=16)
plt.tight_layout()
plt.savefig('Figures/model_comparison_highres.png', dpi=500, bbox_inches='tight')
plt.show()

# %%
colors = {
    'X': '#66C2A6',
    'C': '#FD8D62',
    'N': '#8DA0CB',
    'CO2': '#FED92F',
    'O2': '#A7D854',
    'pH': '#E78AC3',
    'mu': '#B3B3B3'
}

def darken_color(color, factor=0.6):
    rgb = mcolors.to_rgb(color)
    return tuple(factor * c for c in rgb)

fig, axes = plt.subplots(7, 1, figsize=(8, 14))

axes[0].plot(t_casadi_og, X_casadi_og, label='X base', color=colors['X'])
axes[0].plot(t_casadi_O2, X_casadi_O2, '--', label='X O2', color=darken_color(colors['X']))
axes[0].set_title('Biomass (X)')
axes[0].set_xlabel('Time (h)')
axes[0].set_ylabel('X (g/L)')
axes[0].grid(True)
axes[0].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[1].plot(t_casadi_og, C_casadi_og, label='C base', color=colors['C'])
axes[1].plot(t_casadi_O2, C_casadi_O2, '--', label='C O2', color=darken_color(colors['C']))
axes[1].set_title('Glycerol (C)')
axes[1].set_xlabel('Time (h)')
axes[1].set_ylabel('C (g/L)')
axes[1].grid(True)
axes[1].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[2].plot(t_casadi_og, N_casadi_og, label='N base', color=colors['N'])
axes[2].plot(t_casadi_O2, N_casadi_O2, '--', label='N O2', color=darken_color(colors['N']))
axes[2].set_title('Ammonia (N)')
axes[2].set_xlabel('Time (h)')
axes[2].set_ylabel('N (g/L)')
axes[2].grid(True)
axes[2].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[4].plot(t_casadi_og, CO2_casadi_og, label='CO2 base', color=colors['CO2'])
axes[4].plot(t_casadi_O2, CO2_casadi_O2, '--', label='CO2 O2', color=darken_color(colors['CO2']))
axes[4].set_title('Carbon Dioxide (CO2)')
axes[4].set_xlabel('Time (h)')
axes[4].set_ylabel('CO2 (g/L)')
axes[4].grid(True)
axes[4].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[5].plot(t_casadi_O2, O2_casadi_O2, '--', label='O2 O2', color=darken_color(colors['O2']))
axes[5].set_title('Dissolved Oxygen (O2)')
axes[5].set_xlabel('Time (h)')
axes[5].set_ylabel('O2 (g/L)')
axes[5].grid(True)
axes[5].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[3].plot(t_casadi_og, pH_casadi_og, label='pH base', color=colors['pH'])
axes[3].plot(t_casadi_O2, pH_casadi_O2, '--', label='pH O2', color=darken_color(colors['pH']))
axes[3].set_title('pH')
axes[3].set_xlabel('Time (h)')
axes[3].set_ylabel('pH')
axes[3].grid(True)
axes[3].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[6].plot(t_casadi_og, mu_values_casadi_og, label='μ base', color=colors['mu'])
axes[6].plot(t_casadi_O2, mu_values_casadi_O2, '--', label='μ O2', color=darken_color(colors['mu']))
axes[6].set_title('Specific Growth Rate (μ)')
axes[6].set_xlabel('Time (h)')
axes[6].set_ylabel('μ (1/h)')
axes[6].grid(True)
axes[6].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

#fig.suptitle('Comparison between models', fontsize=16)
plt.tight_layout()
plt.savefig('Figures/model_comparison_wo2.png', dpi=500, bbox_inches='tight')
plt.show()
