# %% [markdown]
# # Libraries

# %%
import time
import copy

import casadi as ca
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd
from mealpy import FloatVar, PSO
from mealpy.utils.problem import Problem
from mealpy.utils.problem import FloatVar

from scipy.optimize import root_scalar

from mealpy.swarm_based import PSO
from mealpy.utils.problem import FloatVar
import time

# %% [markdown]
# # Experimental data

# %%
# Experimental data

df_exp = pd.read_excel('DATA_APIYO.xlsx', sheet_name='Datos_normales')
t_exp = df_exp['Time (Hours)']
X_exp = df_exp['Biomass (g/L)']
C_exp = df_exp['Glycerol (g/L)']
N_exp = df_exp['Ammonia (g/L)']
ph_exp = df_exp['pH']
H_exp = df_exp['H']
CO2_exp = df_exp['CO2']

# %% [markdown]
# # Parameters

# %%
# Original parameters
params_values = {'t_lag': 7,
      'k_C': 0.3828,
      'k_N': 1.0027e-4, 
      'Y': {'X_C': 0.484,
      'X_N': 21.575, 
      'X_CO2': 0.3687,
      'X_O2' : 1.352}, 
      'Xmax': 1.4462,  
      'mu_max': 0.19,
      'k_d': 0.001, 
      'pH': {'pka1': 6.86, # pKa of KH2PO4
            'pka2': 3.13,  # pka of C6H8O7
            'pka3': 4.76,  # pka of (C6H7O7)-
            'pka4': 6.40,  # pka of (C6H6O7)2-
            'pka5': 9.25,  # pka of NH3
            'pka6': 14.15, # pka of C3H8O3
            'pka7': 6.35,  # pka of CO2
            'pka8': 10.33, # pka of (HCO3)-
            'pka9': 14,    # pka of H2O
            'conc': {'KH2PO4': 2.18,
                  'C6H8O7': 2},
            'LL': 3.4687,
            'UL': 7.4,
            'alk': 7.2},
      'I_val': 4.0413,
      'pH_M': [0, 14],
      'O2_sat' : 0.007267,
      'k_La' : 86.26,
      'k_O' : 0.0045} 

P_og = params_values['mu_max'],params_values['pH']['UL'],params_values['Y']['X_C'],params_values['Xmax'],params_values['Y']['X_N']
print(P_og)
# Out:
# (0.19, 7.4, 0.484, 1.4462, 21.575)

# %% [markdown]
# # Equations and Solving

# %%
def DAE_system_CasADi_O2(t, vars, z_algebraic, p, params_values):

      # Unpack variables
      X, C, N, CO2, O = vars[0], vars[1], vars[2], vars[3], vars[4]
      w = z_algebraic[0] 

      mu_max = p[0]
      UL = p[1]
      Y_X_C = p[2]
      Xmax = p[3]
      Y_X_N = p[4]
      
      LL = params_values['pH']['LL']  
      Iph = ca.exp((params_values['I_val'] * ((w - UL) / (UL - LL))) ** 2)

      # Specific growth rate
      mu = (mu_max
            * (1 - ca.exp(-t / params_values['t_lag'])) 
            * (C / (C + params_values['k_C'])) 
            * (N / (N + params_values['k_N'])) 
            * (O / (O + params_values['k_O']))
            * (1 - (X / (Xmax))) 
            * Iph)

      ka7 = 10 ** (-params_values['pH']['pka7'])

      # Differential equations
      dXdt   = (mu- params_values['k_d']) * X                                                                   # Biomass
      dCdt   = - (mu / Y_X_C) * X                                                                               # Glycerol
      dNdt   = - (mu / Y_X_N) * X                                                                               # Ammonia
      dCO2dt = ((mu / params_values['Y']['X_CO2']) * X) - ka7 * (CO2 / (((10 ** -w) / ka7) + 1))                # CO2
      dOdt   = params_values['k_La'] * (params_values['O2_sat'] - O) - (mu / params_values['Y']['X_O2']) * X    # O2

      return ca.vertcat(dXdt, dCdt, dNdt, dCO2dt, dOdt)

# %% [markdown]
# # Ajuste de parametros

# %%
param_names = ['mu_max', 'UL', 'Y["X_C"]', 'Xmax', 'Y["X_N"]']
lb = [0.1, 6,   0.1, 1, 17]     # límites inferiores
ub = [1.0, 8, 1.0, 1.2, 18]     # límites superiores

# %%
def simulate_model(p_vars, x0, params_values):
    # Symbolic variables
    t = ca.MX.sym('t')
    x = ca.MX.sym('x', 5)  # [X, C, N, CO2, O2]
    z = ca.MX.sym('z')     # [pH]

    # Systems's differential equations
    dxdt = DAE_system_CasADi_O2(t, x, z, p_vars, params_values)

    # Algebraic equation
    # Parameters
    ka1 = 10 ** (-params_values['pH']['pka1'])  # KH2PO4
    ka2 = 10 ** (-params_values['pH']['pka2'])  # C6H8O7
    ka3 = 10 ** (-params_values['pH']['pka3'])  # (C6H7O7)-
    ka4 = 10 ** (-params_values['pH']['pka4'])  # (C6H6O7)2-
    ka7 = 10 ** (-params_values['pH']['pka7'])  # CO2
    ka9 = 10 ** (-params_values['pH']['pka9'])  # H2O

    H = 10 ** (-z) 

    # Concentration of charges according to H+ ions
    KHPO4 = params_values['pH']['conc']['KH2PO4'] / ((H / ka1) + 1)
    C6H5O7 = params_values['pH']['conc']['C6H8O7'] / ((H ** 3 / (ka2 * ka3 * ka4)) + (H ** 2 / (ka3 * ka4)) + (H / ka4) + 1)
    C6H6O7 = (H / ka4) * C6H5O7
    C6H7O7 = (H / ka3) * C6H6O7
    HCO3 = x[3] / ((H / ka7) + 1)
    OH = ka9 / H

    f_z = OH + HCO3 + KHPO4 + (3 * C6H5O7) + (2 * C6H6O7) + C6H7O7 - params_values['pH']['alk'] - H

    # CasADi function
    f = ca.Function('f', [t, x, z], [dxdt])


    # Simulation time vector
    
    t_values = t_exp 
    # ODE system
    dae = {'t': t, 'x': x, 'z': z, 'ode': f(t,x,z), 'alg': f_z}
    integrator = ca.integrator('integrator', 'idas', dae, {'grid': t_values, 'output_t0': True})

    # Solve
    sol_casadi = integrator(x0=x0[:-1], z0=x0[-1])
    return sol_casadi

# %%
# Initial conditions
X0 = X_exp[0]  
c0 = C_exp[0] 
n0 = N_exp[0] 
co20 = 0.439 / 1000
o20 = 0.0001
z0 = ph_exp[0]  
x0 = np.array([X0, c0, n0, co20, o20, z0])

# %% [markdown]
# # ajuste datos normales

# %%
def cost_function(p_vars):
    try:
        sol = simulate_model(p_vars,x0, params_values)

        # Extract results
        x = sol['xf'].full().T
        z = sol['zf'].full().T
        X = x[:, 0]
        C = x[:, 1]
        N = x[:, 2]
        CO2 = x[:, 3]
        pH = z[:, 0]
        H = 10 ** (-pH)

        df_results = pd.DataFrame({
            'X': X,
            'C': C,
            'N': N,
            'CO2': CO2,
            'pH': pH,
            'H': H,
        })



        X_sim, C_sim, N_sim, CO2_sim, H_sim = df_results['X'], df_results['C'], df_results['N'], df_results['CO2'], df_results['H']

        err = np.sum((X_sim - X_exp)**2) + np.sum((C_sim - C_exp)**2) + np.sum((N_sim - N_exp)**2) + np.sum((H_sim - H_exp)**2)
        return [err]
    except:
        return [1e6]

# %%
problem = {
    "obj_func": cost_function,
    "bounds": FloatVar(lb=lb, ub=ub),
    "minmax": "min"
}

pso = PSO.OriginalPSO(epoch=200, pop_size=50, c1=2, c2=1.5, w=0.5)
start = time.perf_counter()
g_best = pso.solve(problem)
end = time.perf_counter()

print("Mejores parámetros encontrados:", g_best.solution)
print("Error mínimo:", g_best.target.fitness)
print(f"Tiempo de optimización: {end - start:.2f} s")

p_vars = g_best.solution
p_norm = p_vars
# Out:
# CasADi - 2025-06-26 20:05:36 WARNING("The options 't0', 'tf', 'grid' and 'output_t0' have been deprecated.
# The same functionality is provided by providing additional input arguments to the 'integrator' function, in particular:
#  * Call integrator(..., t0, tf, options) for a single output time, or
#  * Call integrator(..., t0, grid, options) for multiple grid points.
# The legacy 'output_t0' option can be emulated by including or excluding 't0' in 'grid'.
# Backwards compatibility is provided in this release only.") [.../casadi/core/integrator.cpp:692]
# 2025/06/26 08:05:36 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: Solving single objective optimization problem.
# 2025/06/26 08:05:38 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 1, Current best: 0.6213170198913295, Global best: 0.6213170198913295, Runtime: 0.63444 seconds
# 2025/06/26 08:05:38 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 2, Current best: 0.5353376691028885, Global best: 0.5353376691028885, Runtime: 0.62493 seconds
# 2025/06/26 08:05:39 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 3, Current best: 0.5353376691028885, Global best: 0.5353376691028885, Runtime: 0.74955 seconds
# 2025/06/26 08:05:40 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 4, Current best: 0.5353376691028885, Global best: 0.5353376691028885, Runtime: 0.64401 seconds
# 2025/06/26 08:05:40 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 5, Current best: 0.5081869629556958, Global best: 0.5081869629556958, Runtime: 0.63712 seconds
# 2025/06/26 08:05:41 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 6, Current best: 0.4838525129306062, Global best: 0.4838525129306062, Runtime: 0.40420 seconds
# 2025/06/26 08:05:41 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 7, Current best: 0.4711606681307131, Global best: 0.4711606681307131, Runtime: 0.37187 seconds
# 2025/06/26 08:05:41 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 8, Current best: 0.46713384438357464, Global best: 0.46713384438357464, Runtime: 0.36361 seconds
# 2025/06/26 08:05:42 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 9, Current best: 0.46713384438357464, Global best: 0.46713384438357464, Runtime: 0.41499 seconds
# 2025/06/26 08:05:42 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 10, Current best: 0.46465476597510236, Global best: 0.46465476597510236, Runtime: 0.37146 seconds
# 2025/06/26 08:05:43 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 11, Current best: 0.4550661466929544, Global best: 0.4550661466929544, Runtime: 0.37348 seconds
# 2025/06/26 08:05:43 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 12, Current best: 0.4349173133083422, Global best: 0.4349173133083422, Runtime: 0.36907 seconds
# 2025/06/26 08:05:43 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 13, Current best: 0.4318276821451884, Global best: 0.4318276821451884, Runtime: 0.36325 seconds
# 2025/06/26 08:05:44 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 14, Current best: 0.4318276821451884, Global best: 0.4318276821451884, Runtime: 0.38255 seconds
# 2025/06/26 08:05:44 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 15, Current best: 0.4318276821451884, Global best: 0.4318276821451884, Runtime: 0.38541 seconds
# 2025/06/26 08:05:44 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 16, Current best: 0.4318276821451884, Global best: 0.4318276821451884, Runtime: 0.39189 seconds
# 2025/06/26 08:05:45 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 17, Current best: 0.4310190074160269, Global best: 0.4310190074160269, Runtime: 0.38253 seconds
# 2025/06/26 08:05:45 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 18, Current best: 0.4306966457679122, Global best: 0.4306966457679122, Runtime: 0.38337 seconds
# 2025/06/26 08:05:46 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 19, Current best: 0.4306966457679122, Global best: 0.4306966457679122, Runtime: 0.39133 seconds
# 2025/06/26 08:05:46 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 20, Current best: 0.4306966457679122, Global best: 0.4306966457679122, Runtime: 0.45437 seconds
# 2025/06/26 08:05:47 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 21, Current best: 0.4306966457679122, Global best: 0.4306966457679122, Runtime: 0.42139 seconds
# 2025/06/26 08:05:47 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 22, Current best: 0.43067846805222126, Global best: 0.43067846805222126, Runtime: 0.60327 seconds
# 2025/06/26 08:05:48 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 23, Current best: 0.43066946892570196, Global best: 0.43066946892570196, Runtime: 0.37233 seconds
# 2025/06/26 08:05:48 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 24, Current best: 0.43066946892570196, Global best: 0.43066946892570196, Runtime: 0.38736 seconds
# 2025/06/26 08:05:48 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 25, Current best: 0.43066946892570196, Global best: 0.43066946892570196, Runtime: 0.36950 seconds
# 2025/06/26 08:05:49 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 26, Current best: 0.4306683482517795, Global best: 0.4306683482517795, Runtime: 0.41302 seconds
# 2025/06/26 08:05:49 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 27, Current best: 0.43066778826689445, Global best: 0.43066778826689445, Runtime: 0.56508 seconds
# 2025/06/26 08:05:50 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 28, Current best: 0.4306675083634098, Global best: 0.4306675083634098, Runtime: 0.40847 seconds
# 2025/06/26 08:05:50 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 29, Current best: 0.4306673684332879, Global best: 0.4306673684332879, Runtime: 0.39834 seconds
# 2025/06/26 08:05:50 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 30, Current best: 0.4306673684332879, Global best: 0.4306673684332879, Runtime: 0.38303 seconds
# 2025/06/26 08:05:51 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 31, Current best: 0.43066733345299546, Global best: 0.43066733345299546, Runtime: 0.45974 seconds
# 2025/06/26 08:05:51 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 32, Current best: 0.4306673159627645, Global best: 0.4306673159627645, Runtime: 0.57305 seconds
# 2025/06/26 08:05:52 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 33, Current best: 0.4306673159627645, Global best: 0.4306673159627645, Runtime: 0.50440 seconds
# 2025/06/26 08:05:52 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 34, Current best: 0.4306673115898456, Global best: 0.4306673115898456, Runtime: 0.41674 seconds
# 2025/06/26 08:05:53 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 35, Current best: 0.43066730940382747, Global best: 0.43066730940382747, Runtime: 0.40990 seconds
# 2025/06/26 08:05:53 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 36, Current best: 0.43066730940382747, Global best: 0.43066730940382747, Runtime: 0.44237 seconds
# 2025/06/26 08:05:54 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 37, Current best: 0.4306673088574716, Global best: 0.4306673088574716, Runtime: 0.37045 seconds
# 2025/06/26 08:05:54 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 38, Current best: 0.43066730858455593, Global best: 0.43066730858455593, Runtime: 0.43109 seconds
# 2025/06/26 08:05:55 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 39, Current best: 0.4306673084479752, Global best: 0.4306673084479752, Runtime: 0.46013 seconds
# 2025/06/26 08:05:55 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 40, Current best: 0.43066730837972234, Global best: 0.43066730837972234, Runtime: 0.63071 seconds
# 2025/06/26 08:05:56 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 41, Current best: 0.43066730834526556, Global best: 0.43066730834526556, Runtime: 0.40044 seconds
# 2025/06/26 08:05:56 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 42, Current best: 0.43066730832828465, Global best: 0.43066730832828465, Runtime: 0.60986 seconds
# 2025/06/26 08:05:57 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 43, Current best: 0.43066730832828465, Global best: 0.43066730832828465, Runtime: 0.48765 seconds
# 2025/06/26 08:05:57 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 44, Current best: 0.43066730832399186, Global best: 0.43066730832399186, Runtime: 0.39526 seconds
# 2025/06/26 08:05:57 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 45, Current best: 0.4306673083218393, Global best: 0.4306673083218393, Runtime: 0.38164 seconds
# 2025/06/26 08:05:58 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 46, Current best: 0.4306673083207978, Global best: 0.4306673083207978, Runtime: 0.48911 seconds
# 2025/06/26 08:05:58 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 47, Current best: 0.4306673083207978, Global best: 0.4306673083207978, Runtime: 0.46757 seconds
# 2025/06/26 08:05:59 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 48, Current best: 0.4306673083207978, Global best: 0.4306673083207978, Runtime: 0.44641 seconds
# 2025/06/26 08:05:59 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 49, Current best: 0.4306673083207978, Global best: 0.4306673083207978, Runtime: 0.38203 seconds
# 2025/06/26 08:06:00 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 50, Current best: 0.4306673083207978, Global best: 0.4306673083207978, Runtime: 0.38037 seconds
# 2025/06/26 08:06:00 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 51, Current best: 0.4306673083207978, Global best: 0.4306673083207978, Runtime: 0.40751 seconds
# 2025/06/26 08:06:00 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 52, Current best: 0.4306673083207978, Global best: 0.4306673083207978, Runtime: 0.47989 seconds
# 2025/06/26 08:06:01 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 53, Current best: 0.4306673083207978, Global best: 0.4306673083207978, Runtime: 0.49075 seconds
# 2025/06/26 08:06:01 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 54, Current best: 0.43063693293325167, Global best: 0.43063693293325167, Runtime: 0.38596 seconds
# 2025/06/26 08:06:02 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 55, Current best: 0.4306301741798358, Global best: 0.4306301741798358, Runtime: 0.38728 seconds
# 2025/06/26 08:06:02 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 56, Current best: 0.4306067873256123, Global best: 0.4306067873256123, Runtime: 0.36982 seconds
# 2025/06/26 08:06:03 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 57, Current best: 0.4305960102373251, Global best: 0.4305960102373251, Runtime: 0.40122 seconds
# 2025/06/26 08:06:03 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 58, Current best: 0.4305880723110931, Global best: 0.4305880723110931, Runtime: 0.40994 seconds
# 2025/06/26 08:06:03 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 59, Current best: 0.4305141708449631, Global best: 0.4305141708449631, Runtime: 0.39079 seconds
# 2025/06/26 08:06:04 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 60, Current best: 0.4305141708449631, Global best: 0.4305141708449631, Runtime: 0.40451 seconds
# 2025/06/26 08:06:04 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 61, Current best: 0.4305141708449631, Global best: 0.4305141708449631, Runtime: 0.42467 seconds
# 2025/06/26 08:06:05 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 62, Current best: 0.4305141708449631, Global best: 0.4305141708449631, Runtime: 0.43195 seconds
# 2025/06/26 08:06:05 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 63, Current best: 0.4304971925314077, Global best: 0.4304971925314077, Runtime: 0.41412 seconds
# 2025/06/26 08:06:05 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 64, Current best: 0.4304162678612101, Global best: 0.4304162678612101, Runtime: 0.36454 seconds
# 2025/06/26 08:06:06 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 65, Current best: 0.43033286836251916, Global best: 0.43033286836251916, Runtime: 0.54553 seconds
# 2025/06/26 08:06:06 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 66, Current best: 0.4302557334845739, Global best: 0.4302557334845739, Runtime: 0.49319 seconds
# 2025/06/26 08:06:07 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 67, Current best: 0.4301920793338845, Global best: 0.4301920793338845, Runtime: 0.40417 seconds
# 2025/06/26 08:06:07 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 68, Current best: 0.43013714545811665, Global best: 0.43013714545811665, Runtime: 0.39827 seconds
# 2025/06/26 08:06:08 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 69, Current best: 0.43010901643091987, Global best: 0.43010901643091987, Runtime: 0.46569 seconds
# 2025/06/26 08:06:08 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 70, Current best: 0.4300666046134157, Global best: 0.4300666046134157, Runtime: 0.38186 seconds
# 2025/06/26 08:06:08 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 71, Current best: 0.43001035102524604, Global best: 0.43001035102524604, Runtime: 0.36859 seconds
# 2025/06/26 08:06:09 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 72, Current best: 0.42952942899054203, Global best: 0.42952942899054203, Runtime: 0.42514 seconds
# 2025/06/26 08:06:09 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 73, Current best: 0.4291639884982242, Global best: 0.4291639884982242, Runtime: 0.39671 seconds
# 2025/06/26 08:06:10 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 74, Current best: 0.42901784637816504, Global best: 0.42901784637816504, Runtime: 0.36121 seconds
# 2025/06/26 08:06:10 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 75, Current best: 0.42893290183677346, Global best: 0.42893290183677346, Runtime: 0.52411 seconds
# 2025/06/26 08:06:11 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 76, Current best: 0.42893290183677346, Global best: 0.42893290183677346, Runtime: 0.37800 seconds
# 2025/06/26 08:06:11 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 77, Current best: 0.42867881121273677, Global best: 0.42867881121273677, Runtime: 0.39641 seconds
# 2025/06/26 08:06:11 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 78, Current best: 0.42867881121273677, Global best: 0.42867881121273677, Runtime: 0.38617 seconds
# 2025/06/26 08:06:12 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 79, Current best: 0.42863907940084545, Global best: 0.42863907940084545, Runtime: 0.39348 seconds
# 2025/06/26 08:06:12 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 80, Current best: 0.428590191627622, Global best: 0.428590191627622, Runtime: 0.37423 seconds
# 2025/06/26 08:06:12 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 81, Current best: 0.428590191627622, Global best: 0.428590191627622, Runtime: 0.36754 seconds
# 2025/06/26 08:06:13 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 82, Current best: 0.428590191627622, Global best: 0.428590191627622, Runtime: 0.46977 seconds
# 2025/06/26 08:06:13 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 83, Current best: 0.428590191627622, Global best: 0.428590191627622, Runtime: 0.37529 seconds
# 2025/06/26 08:06:14 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 84, Current best: 0.4285868703495572, Global best: 0.4285868703495572, Runtime: 0.37716 seconds
# 2025/06/26 08:06:14 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 85, Current best: 0.42855122951105823, Global best: 0.42855122951105823, Runtime: 0.42221 seconds
# 2025/06/26 08:06:15 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 86, Current best: 0.42855122951105823, Global best: 0.42855122951105823, Runtime: 0.39297 seconds
# 2025/06/26 08:06:15 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 87, Current best: 0.4285461248167243, Global best: 0.4285461248167243, Runtime: 0.51022 seconds
# 2025/06/26 08:06:15 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 88, Current best: 0.4285379217101806, Global best: 0.4285379217101806, Runtime: 0.44084 seconds
# 2025/06/26 08:06:16 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 89, Current best: 0.42853637918383186, Global best: 0.42853637918383186, Runtime: 0.43912 seconds
# 2025/06/26 08:06:16 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 90, Current best: 0.42852942918036435, Global best: 0.42852942918036435, Runtime: 0.38501 seconds
# 2025/06/26 08:06:17 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 91, Current best: 0.42851778269763724, Global best: 0.42851778269763724, Runtime: 0.37760 seconds
# 2025/06/26 08:06:17 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 92, Current best: 0.4285117096888709, Global best: 0.4285117096888709, Runtime: 0.41846 seconds
# 2025/06/26 08:06:18 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 93, Current best: 0.42850326267825334, Global best: 0.42850326267825334, Runtime: 0.43614 seconds
# 2025/06/26 08:06:18 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 94, Current best: 0.42849774297620485, Global best: 0.42849774297620485, Runtime: 0.40852 seconds
# 2025/06/26 08:06:18 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 95, Current best: 0.4284953034210137, Global best: 0.4284953034210137, Runtime: 0.44249 seconds
# 2025/06/26 08:06:19 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 96, Current best: 0.4284936864077222, Global best: 0.4284936864077222, Runtime: 0.45610 seconds
# 2025/06/26 08:06:19 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 97, Current best: 0.4284911092475366, Global best: 0.4284911092475366, Runtime: 0.40800 seconds
# 2025/06/26 08:06:20 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 98, Current best: 0.4284911092475366, Global best: 0.4284911092475366, Runtime: 0.42000 seconds
# 2025/06/26 08:06:20 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 99, Current best: 0.42849050930914745, Global best: 0.42849050930914745, Runtime: 0.42223 seconds
# 2025/06/26 08:06:20 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 100, Current best: 0.4284903240912238, Global best: 0.4284903240912238, Runtime: 0.35899 seconds
# 2025/06/26 08:06:21 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 101, Current best: 0.42848966778122594, Global best: 0.42848966778122594, Runtime: 0.70772 seconds
# 2025/06/26 08:06:22 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 102, Current best: 0.42848966778122594, Global best: 0.42848966778122594, Runtime: 0.42357 seconds
# 2025/06/26 08:06:22 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 103, Current best: 0.42848966778122594, Global best: 0.42848966778122594, Runtime: 0.38093 seconds
# 2025/06/26 08:06:22 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 104, Current best: 0.42848966778122594, Global best: 0.42848966778122594, Runtime: 0.41668 seconds
# 2025/06/26 08:06:23 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 105, Current best: 0.42848966778122594, Global best: 0.42848966778122594, Runtime: 0.53440 seconds
# 2025/06/26 08:06:23 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 106, Current best: 0.42848966778122594, Global best: 0.42848966778122594, Runtime: 0.36085 seconds
# 2025/06/26 08:06:24 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 107, Current best: 0.42848966778122594, Global best: 0.42848966778122594, Runtime: 0.37073 seconds
# 2025/06/26 08:06:24 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 108, Current best: 0.42848966778122594, Global best: 0.42848966778122594, Runtime: 0.70898 seconds
# 2025/06/26 08:06:25 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 109, Current best: 0.4284896657502445, Global best: 0.4284896657502445, Runtime: 0.65636 seconds
# 2025/06/26 08:06:25 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 110, Current best: 0.4284896657502445, Global best: 0.4284896657502445, Runtime: 0.36297 seconds
# 2025/06/26 08:06:26 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 111, Current best: 0.4284896657502445, Global best: 0.4284896657502445, Runtime: 0.44328 seconds
# 2025/06/26 08:06:26 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 112, Current best: 0.42848966550637363, Global best: 0.42848966550637363, Runtime: 0.36709 seconds
# 2025/06/26 08:06:27 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 113, Current best: 0.42848966550637363, Global best: 0.42848966550637363, Runtime: 0.40166 seconds
# 2025/06/26 08:06:27 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 114, Current best: 0.42848966550637363, Global best: 0.42848966550637363, Runtime: 0.37410 seconds
# 2025/06/26 08:06:27 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 115, Current best: 0.4284896654757826, Global best: 0.4284896654757826, Runtime: 0.52760 seconds
# 2025/06/26 08:06:28 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 116, Current best: 0.4284896654757826, Global best: 0.4284896654757826, Runtime: 0.51638 seconds
# 2025/06/26 08:06:28 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 117, Current best: 0.4284896654757826, Global best: 0.4284896654757826, Runtime: 0.36636 seconds
# 2025/06/26 08:06:29 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 118, Current best: 0.4284896654692113, Global best: 0.4284896654692113, Runtime: 0.37144 seconds
# 2025/06/26 08:06:29 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 119, Current best: 0.4284896624704216, Global best: 0.4284896624704216, Runtime: 0.36634 seconds
# 2025/06/26 08:06:29 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 120, Current best: 0.4284896621167363, Global best: 0.4284896621167363, Runtime: 0.36715 seconds
# 2025/06/26 08:06:30 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 121, Current best: 0.4284896604520545, Global best: 0.4284896604520545, Runtime: 0.37600 seconds
# 2025/06/26 08:06:30 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 122, Current best: 0.4284896450219982, Global best: 0.4284896450219982, Runtime: 0.37269 seconds
# 2025/06/26 08:06:31 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 123, Current best: 0.4284896318096419, Global best: 0.4284896318096419, Runtime: 0.37535 seconds
# 2025/06/26 08:06:31 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 124, Current best: 0.42848962022749115, Global best: 0.42848962022749115, Runtime: 0.37462 seconds
# 2025/06/26 08:06:31 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 125, Current best: 0.42848962022749115, Global best: 0.42848962022749115, Runtime: 0.36827 seconds
# 2025/06/26 08:06:32 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 126, Current best: 0.428489610199223, Global best: 0.428489610199223, Runtime: 0.39517 seconds
# 2025/06/26 08:06:32 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 127, Current best: 0.42848960628326593, Global best: 0.42848960628326593, Runtime: 0.41967 seconds
# 2025/06/26 08:06:33 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 128, Current best: 0.4284896016454838, Global best: 0.4284896016454838, Runtime: 0.35910 seconds
# 2025/06/26 08:06:33 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 129, Current best: 0.4284895931169211, Global best: 0.4284895931169211, Runtime: 0.36973 seconds
# 2025/06/26 08:06:33 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 130, Current best: 0.42848958082524713, Global best: 0.42848958082524713, Runtime: 0.37091 seconds
# 2025/06/26 08:06:34 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 131, Current best: 0.4284895738291459, Global best: 0.4284895738291459, Runtime: 0.36500 seconds
# 2025/06/26 08:06:34 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 132, Current best: 0.4284895652795226, Global best: 0.4284895652795226, Runtime: 0.37355 seconds
# 2025/06/26 08:06:34 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 133, Current best: 0.4284895603672394, Global best: 0.4284895603672394, Runtime: 0.37868 seconds
# 2025/06/26 08:06:35 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 134, Current best: 0.428489556083215, Global best: 0.428489556083215, Runtime: 0.46554 seconds
# 2025/06/26 08:06:35 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 135, Current best: 0.42848955318805515, Global best: 0.42848955318805515, Runtime: 0.38144 seconds
# 2025/06/26 08:06:36 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 136, Current best: 0.4284895498379618, Global best: 0.4284895498379618, Runtime: 0.38165 seconds
# 2025/06/26 08:06:36 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 137, Current best: 0.4284895397244645, Global best: 0.4284895397244645, Runtime: 0.78747 seconds
# 2025/06/26 08:06:37 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 138, Current best: 0.4284895340498894, Global best: 0.4284895340498894, Runtime: 0.36383 seconds
# 2025/06/26 08:06:37 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 139, Current best: 0.42848952770861737, Global best: 0.42848952770861737, Runtime: 0.49857 seconds
# 2025/06/26 08:06:38 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 140, Current best: 0.42848951709807576, Global best: 0.42848951709807576, Runtime: 0.66545 seconds
# 2025/06/26 08:06:38 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 141, Current best: 0.4284894973314585, Global best: 0.4284894973314585, Runtime: 0.41410 seconds
# 2025/06/26 08:06:39 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 142, Current best: 0.4284894894452627, Global best: 0.4284894894452627, Runtime: 0.36277 seconds
# 2025/06/26 08:06:39 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 143, Current best: 0.42848947686435657, Global best: 0.42848947686435657, Runtime: 0.38513 seconds
# 2025/06/26 08:06:40 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 144, Current best: 0.4284894562247334, Global best: 0.4284894562247334, Runtime: 0.57800 seconds
# 2025/06/26 08:06:40 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 145, Current best: 0.4284894493449765, Global best: 0.4284894493449765, Runtime: 0.39027 seconds
# 2025/06/26 08:06:40 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 146, Current best: 0.4284894305990057, Global best: 0.4284894305990057, Runtime: 0.40293 seconds
# 2025/06/26 08:06:41 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 147, Current best: 0.4284894134959391, Global best: 0.4284894134959391, Runtime: 0.43420 seconds
# 2025/06/26 08:06:41 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 148, Current best: 0.42848939600381675, Global best: 0.42848939600381675, Runtime: 0.40607 seconds
# 2025/06/26 08:06:42 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 149, Current best: 0.42848937575017565, Global best: 0.42848937575017565, Runtime: 0.42225 seconds
# 2025/06/26 08:06:42 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 150, Current best: 0.4284893584895604, Global best: 0.4284893584895604, Runtime: 0.45358 seconds
# 2025/06/26 08:06:43 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 151, Current best: 0.42848933747052054, Global best: 0.42848933747052054, Runtime: 0.62925 seconds
# 2025/06/26 08:06:43 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 152, Current best: 0.4284893180686323, Global best: 0.4284893180686323, Runtime: 0.61273 seconds
# 2025/06/26 08:06:44 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 153, Current best: 0.42848930249717915, Global best: 0.42848930249717915, Runtime: 0.51569 seconds
# 2025/06/26 08:06:45 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 154, Current best: 0.42848928520249735, Global best: 0.42848928520249735, Runtime: 0.53956 seconds
# 2025/06/26 08:06:45 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 155, Current best: 0.42848926914167773, Global best: 0.42848926914167773, Runtime: 0.50093 seconds
# 2025/06/26 08:06:46 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 156, Current best: 0.42848925793964615, Global best: 0.42848925793964615, Runtime: 0.49109 seconds
# 2025/06/26 08:06:46 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 157, Current best: 0.4284892449613422, Global best: 0.4284892449613422, Runtime: 0.52178 seconds
# 2025/06/26 08:06:46 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 158, Current best: 0.4284892360358262, Global best: 0.4284892360358262, Runtime: 0.45665 seconds
# 2025/06/26 08:06:47 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 159, Current best: 0.4284892285839242, Global best: 0.4284892285839242, Runtime: 0.40847 seconds
# 2025/06/26 08:06:47 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 160, Current best: 0.4284892228092626, Global best: 0.4284892228092626, Runtime: 0.40079 seconds
# 2025/06/26 08:06:48 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 161, Current best: 0.4284892155715292, Global best: 0.4284892155715292, Runtime: 0.62711 seconds
# 2025/06/26 08:06:48 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 162, Current best: 0.42848920916067806, Global best: 0.42848920916067806, Runtime: 0.51690 seconds
# 2025/06/26 08:06:49 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 163, Current best: 0.428489204396997, Global best: 0.428489204396997, Runtime: 0.56235 seconds
# 2025/06/26 08:06:49 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 164, Current best: 0.4284891999626565, Global best: 0.4284891999626565, Runtime: 0.39056 seconds
# 2025/06/26 08:06:50 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 165, Current best: 0.42848919585310713, Global best: 0.42848919585310713, Runtime: 0.39392 seconds
# 2025/06/26 08:06:50 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 166, Current best: 0.4284891919459897, Global best: 0.4284891919459897, Runtime: 0.38599 seconds
# 2025/06/26 08:06:51 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 167, Current best: 0.4284891884961433, Global best: 0.4284891884961433, Runtime: 0.40099 seconds
# 2025/06/26 08:06:51 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 168, Current best: 0.428489184733966, Global best: 0.428489184733966, Runtime: 0.36616 seconds
# 2025/06/26 08:06:51 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 169, Current best: 0.4284891811431065, Global best: 0.4284891811431065, Runtime: 0.42672 seconds
# 2025/06/26 08:06:52 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 170, Current best: 0.4284889956073748, Global best: 0.4284889956073748, Runtime: 0.44299 seconds
# 2025/06/26 08:06:52 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 171, Current best: 0.4284889191215101, Global best: 0.4284889191215101, Runtime: 0.39023 seconds
# 2025/06/26 08:06:53 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 172, Current best: 0.42848879560986336, Global best: 0.42848879560986336, Runtime: 0.42419 seconds
# 2025/06/26 08:06:53 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 173, Current best: 0.42848871734346133, Global best: 0.42848871734346133, Runtime: 0.40564 seconds
# 2025/06/26 08:06:53 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 174, Current best: 0.4284885045794807, Global best: 0.4284885045794807, Runtime: 0.37066 seconds
# 2025/06/26 08:06:54 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 175, Current best: 0.42848840285824885, Global best: 0.42848840285824885, Runtime: 0.37845 seconds
# 2025/06/26 08:06:54 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 176, Current best: 0.4284882616254627, Global best: 0.4284882616254627, Runtime: 0.35962 seconds
# 2025/06/26 08:06:55 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 177, Current best: 0.42848807806039524, Global best: 0.42848807806039524, Runtime: 0.36425 seconds
# 2025/06/26 08:06:55 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 178, Current best: 0.4284878939886604, Global best: 0.4284878939886604, Runtime: 0.41604 seconds
# 2025/06/26 08:06:55 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 179, Current best: 0.42848787174937786, Global best: 0.42848787174937786, Runtime: 0.37044 seconds
# 2025/06/26 08:06:56 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 180, Current best: 0.4284878236159318, Global best: 0.4284878236159318, Runtime: 0.36024 seconds
# 2025/06/26 08:06:56 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 181, Current best: 0.42848779687047894, Global best: 0.42848779687047894, Runtime: 0.37685 seconds
# 2025/06/26 08:06:56 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 182, Current best: 0.4284876460746138, Global best: 0.4284876460746138, Runtime: 0.40658 seconds
# 2025/06/26 08:06:57 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 183, Current best: 0.42848745210678685, Global best: 0.42848745210678685, Runtime: 0.43143 seconds
# 2025/06/26 08:06:57 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 184, Current best: 0.4284870127143905, Global best: 0.4284870127143905, Runtime: 0.37872 seconds
# 2025/06/26 08:06:58 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 185, Current best: 0.42848666990124623, Global best: 0.42848666990124623, Runtime: 0.61400 seconds
# 2025/06/26 08:06:58 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 186, Current best: 0.4284864521369726, Global best: 0.4284864521369726, Runtime: 0.36558 seconds
# 2025/06/26 08:06:59 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 187, Current best: 0.4284859474818199, Global best: 0.4284859474818199, Runtime: 0.36911 seconds
# 2025/06/26 08:06:59 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 188, Current best: 0.42848569485824883, Global best: 0.42848569485824883, Runtime: 0.38049 seconds
# 2025/06/26 08:06:59 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 189, Current best: 0.42848531668345535, Global best: 0.42848531668345535, Runtime: 0.37488 seconds
# 2025/06/26 08:07:00 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 190, Current best: 0.4284849865247082, Global best: 0.4284849865247082, Runtime: 0.38705 seconds
# 2025/06/26 08:07:00 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 191, Current best: 0.42848285388106044, Global best: 0.42848285388106044, Runtime: 0.36234 seconds
# 2025/06/26 08:07:01 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 192, Current best: 0.42848285388106044, Global best: 0.42848285388106044, Runtime: 0.37677 seconds
# 2025/06/26 08:07:01 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 193, Current best: 0.42848158506046014, Global best: 0.42848158506046014, Runtime: 0.35878 seconds
# 2025/06/26 08:07:01 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 194, Current best: 0.4284809390784065, Global best: 0.4284809390784065, Runtime: 0.36101 seconds
# 2025/06/26 08:07:02 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 195, Current best: 0.42847834327835527, Global best: 0.42847834327835527, Runtime: 0.36824 seconds
# 2025/06/26 08:07:02 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 196, Current best: 0.42847690914237846, Global best: 0.42847690914237846, Runtime: 0.37017 seconds
# 2025/06/26 08:07:02 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 197, Current best: 0.42847486379286787, Global best: 0.42847486379286787, Runtime: 0.38178 seconds
# 2025/06/26 08:07:03 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 198, Current best: 0.4284642025694462, Global best: 0.4284642025694462, Runtime: 0.38797 seconds
# 2025/06/26 08:07:03 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 199, Current best: 0.4284565343333159, Global best: 0.4284565343333159, Runtime: 0.37992 seconds
# 2025/06/26 08:07:04 PM, INFO, mealpy.swarm_based.PSO.OriginalPSO: >>>Problem: P, Epoch: 200, Current best: 0.42845269795080626, Global best: 0.42845269795080626, Runtime: 0.38380 seconds
# Mejores parámetros encontrados: [ 0.11557996  8.          0.53856751  1.19999991 17.74102606]
# Error mínimo: 0.42845269795080626
# Tiempo de optimización: 87.19 s

# %%
sol = simulate_model(p_norm, x0, params_values)
sol1 = simulate_model(P_og, x0, params_values)

best_sim = sol['xf'].full().T 
solz = sol['zf'].full().T  
best_sim1 = sol1['xf'].full().T  
solz1 = sol1['zf'].full().T  

colors = {
    'X': 'tab:blue',
    'C': 'tab:orange',
    'N': 'tab:green',
    'CO2': 'tab:red',
    'O2': 'tab:purple',
    'pH': 'tab:brown',
    'mu': 'tab:gray'
}

def darken_color(color, factor=0.6):
    rgb = mcolors.to_rgb(color)
    return tuple(factor * c for c in rgb)

fig, axes = plt.subplots(4, 1, figsize=(8, 14))


axes[0].scatter(t_exp, X_exp, marker='o', label="Biomasa exp",color=colors['X'])
axes[0].plot(t_exp, best_sim[:, 0], '-', label="Biomasa sim",color=colors['X'])
axes[0].plot(t_exp, best_sim1[:, 0], '--', label="Biomasa sim (original)",color=darken_color(colors['X']))
axes[0].set_xlabel("Tiempo (h)")
axes[0].set_ylabel("Concentración")
axes[0].set_title("Ajuste del modelo con PSO")
axes[0].legend()
axes[0].grid(True)



axes[1].scatter(t_exp, C_exp, marker='s', label="Glicerol exp",color=colors['C'])
axes[1].plot(t_exp, best_sim[:, 1], '-', label="Glicerol sim",color=colors['C'])
axes[1].plot(t_exp, best_sim1[:, 1], '--', label="Glicerol sim (original)",color=darken_color(colors['C']))
axes[1].set_xlabel("Tiempo (h)")
axes[1].set_ylabel("Concentración")
axes[1].set_title("Ajuste del modelo con PSO")
axes[1].legend()
axes[1].grid(True)



axes[2].scatter(t_exp, N_exp,marker= '^', label="Amonio exp",color=colors['N'])
axes[2].plot(t_exp, best_sim[:, 2], '-', label="Amonio sim",color=colors['N'])
axes[2].plot(t_exp, best_sim1[:, 2], '--', label="Amonio sim (original)",color=darken_color(colors['N']))
axes[2].set_xlabel("Tiempo (h)")
axes[2].set_ylabel("Concentración")
axes[2].set_title("Ajuste del modelo con PSO")
axes[2].legend()
axes[2].grid(True)



axes[3].scatter(t_exp, ph_exp, marker='*', label="PH exp",color=colors['pH'])
axes[3].plot(t_exp, solz[:, 0], '-', label="PH sim",color=colors['pH'])
axes[3].plot(t_exp, solz1[:, 0], '--', label="PH sim (original)",color=darken_color(colors['pH']))
axes[3].set_xlabel("Tiempo (h)")
axes[3].set_ylabel("Concentración")
axes[3].set_title("Ajuste del modelo con PSO")
axes[3].legend()
axes[3].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Comparación de parametros

# %%
df_params = pd.DataFrame({
    "Parámetro": param_names,
    "p_og": P_og,
    "p_norm": p_norm
})

df_params
# Out:
#   Parámetro     p_og     p_norm
# 0    mu_max   0.1900   0.115580
# 1        UL   7.4000   8.000000
# 2  Y["X_C"]   0.4840   0.538568
# 3      Xmax   1.4462   1.200000
# 4  Y["X_N"]  21.5750  17.741026

# %% [markdown]
# # validacion

# %%
# Experimental data

df_exp_v = pd.read_excel('DATA_APIYO.xlsx', sheet_name='Validation_n')
t_exp = df_exp_v['Time (hours)']
X_exp_v = df_exp_v['Biomass (g/L)']
C_exp_v = df_exp_v['Glycerol (g/L)']
N_exp_v = df_exp_v['Ammonia (g/L)']
ph_exp_v = df_exp_v['pH']
H_exp_v = df_exp_v['H']

# %%
# Initial conditions
X0 = X_exp_v[0]
c0 = C_exp_v[0]
n0 = N_exp_v[0]
co20 = 0.439 / 1000
o20 = 0.0001
z0 = ph_exp[0]  
x0 = np.array([X0, c0, n0, co20, o20, z0])

# %%
sol = simulate_model(p_norm, x0, params_values)
sol1 = simulate_model(P_og, x0, params_values)

best_sim = sol['xf'].full().T  
solz = sol['zf'].full().T  
best_sim1 = sol1['xf'].full().T  
solz1 = sol1['zf'].full().T  

colors = {
    'X': 'tab:blue',
    'C': 'tab:orange',
    'N': 'tab:green',
    'CO2': 'tab:red',
    'O2': 'tab:purple',
    'pH': 'tab:brown',
    'mu': 'tab:gray'
}

def darken_color(color, factor=0.6):
    rgb = mcolors.to_rgb(color)
    return tuple(factor * c for c in rgb)

fig, axes = plt.subplots(4, 1, figsize=(8, 10))

t_casadi_O2 = np.linspace(0, 80, 501)
# Biomass
axes[0].plot(t_exp, best_sim[:, 0], label='New', color=colors['X'])
axes[0].plot(t_exp, best_sim1[:, 0] ,'--',label='Original', color=colors['X'])
axes[0].scatter(t_exp, X_exp_v, label='Validation', color=darken_color(colors['X']), marker='o')
axes[0].set_title('Biomass (X)')
axes[0].set_xlabel('Time (h)')
axes[0].set_ylabel('X (g/L)')
axes[0].grid(True)
axes[0].legend()

# Glycerol
axes[1].plot(t_exp, best_sim[:, 1], label='new', color=colors['C'])
axes[1].plot(t_exp, best_sim1[:, 1] ,'--',label='Original', color=colors['C'])
axes[1].scatter(t_exp, C_exp_v, label='Validation', color=darken_color(colors['C']), marker='o')
axes[1].set_title('Glycerol (C)')
axes[1].set_xlabel('Time (h)')
axes[1].set_ylabel('C (g/L)')
axes[1].grid(True)
axes[1].legend()

# Ammonia
axes[2].plot(t_exp, best_sim[:, 2], label='New', color=colors['N'])
axes[2].plot(t_exp, best_sim1[:, 2] ,'--',label='Original', color=colors['N'])
axes[2].scatter(t_exp, N_exp_v, label='Validation', color=darken_color(colors['N']), marker='o')
axes[2].set_title('Ammonia (N)')
axes[2].set_xlabel('Time (h)')
axes[2].set_ylabel('N (g/L)')
axes[2].grid(True)
axes[2].legend()

# pH
axes[3].plot(t_exp, solz[:, 0], label='New', color=colors['pH'])
axes[3].plot(t_exp, solz1[:, 0] ,'--',label='Original', color=colors['pH'])
axes[3].scatter(t_exp, ph_exp_v, label='Validation', color=darken_color(colors['pH']), marker='o')
axes[3].set_title('pH')
axes[3].set_xlabel('Time (h)')
axes[3].set_ylabel('pH')
axes[3].grid(True)
axes[3].legend()

fig.suptitle('Model Prediction vs Validation Data, 4 parameter set', fontsize=16)
plt.tight_layout()
plt.show()

# %%
import numpy as np


X_exp = X_exp_v    
C_exp = C_exp_v
N_exp = N_exp_v
pH_exp = ph_exp_v


X_sim = best_sim[:, 0]
C_sim = best_sim[:, 1]
N_sim = best_sim[:, 2]
pH_sim = solz[:, 0]


y_exp = np.concatenate([X_exp, C_exp, N_exp, pH_exp])
y_sim = np.concatenate([X_sim, C_sim, N_sim, pH_sim])
y_sim_og = np.concatenate([best_sim1[:, 0], best_sim1[:, 1], best_sim1[:, 2], solz1[:, 0]])



n = len(y_exp)
k = len(param_names)  


def rmse(y_true, y_pred):
    return np.sqrt(np.mean((y_true - y_pred)**2))

def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def nrmse(y_true, y_pred):
    return rmse(y_true, y_pred) / (np.max(y_true) - np.min(y_true))  

#RMSE, MAPE y NRMSE por variable
print("\nMétricas por variable (nuevo modelo):")
for label, y_e, y_s in zip(['X', 'C', 'N', 'pH'], [X_exp, C_exp, N_exp, pH_exp], [X_sim, C_sim, N_sim, pH_sim]):
    print(f"{label}:")
    print(f"  RMSE:   {rmse(y_e, y_s):.4f}")
    print(f"  NRMSE:  {nrmse(y_e, y_s):.4f}")
    print(f"  MAPE:   {mape(y_e, y_s):.2f} %")

#RMSE, MAPE y NRMSE por variable (modelo original)
print("\nMétricas por variable (modelo original):")
for label, y_e, y_s in zip(['X', 'C', 'N', 'pH'], [X_exp, C_exp, N_exp, pH_exp], 
                                        [best_sim1[:, 0], best_sim1[:, 1], best_sim1[:, 2], solz1[:, 0]]):
    print(f"{label}:")
    print(f"  RMSE:   {rmse(y_e, y_s):.4f}")
    print(f"  NRMSE:  {nrmse(y_e, y_s):.4f}")
    print(f"  MAPE:   {mape(y_e, y_s):.2f} %")

#Métricas globales
rss = np.sum((y_exp - y_sim)**2)
rss_og = np.sum((y_exp - y_sim_og)**2)

aic_new = 2 * k + n * np.log(rss / n)
bic_new = k * np.log(n) + n * np.log(rss / n)

aic_og = 2 * k + n * np.log(rss_og / n)
bic_og = k * np.log(n) + n * np.log(rss_og / n)

print("\nMétricas globales:")
print(f"AIC (nuevo modelo): {aic_new:.2f}")
print(f"BIC (nuevo modelo): {bic_new:.2f}")
print(f"AIC (modelo original): {aic_og:.2f}")
print(f"BIC (modelo original): {bic_og:.2f}")
print(f"RMSE (nuevo modelo): {rmse(y_exp, y_sim):.4f}")
print(f"RMSE (modelo original): {rmse(y_exp, y_sim_og):.4f}")
print(f"NMRSE (nuevo modelo): {nrmse(y_exp, y_sim):.4f}")
print(f"NMRSE (modelo original): {nrmse(y_exp, y_sim_og):.4f}")
print(f"MAPE (nuevo modelo): {mape(y_exp, y_sim):.2f} %")
print(f"MAPE (modelo original): {mape(y_exp, y_sim_og):.2f} %")
# Out:
# Métricas por variable (nuevo modelo):
# X:
#   RMSE:   0.1236
#   NRMSE:  0.1260
#   MAPE:   10.50 %
# C:
#   RMSE:   0.2725
#   NRMSE:  0.1021
#   MAPE:   5.33 %
# N:
#   RMSE:   0.0462
#   NRMSE:  0.2790
#   MAPE:   3.74 %
# pH:
#   RMSE:   0.0386
#   NRMSE:  0.0482
#   MAPE:   0.51 %
#
# Métricas por variable (modelo original):
# X:
#   RMSE:   0.2880
#   NRMSE:  0.2935
#   MAPE:   24.25 %
# C:
#   RMSE:   0.5594
#   NRMSE:  0.2096
#   MAPE:   10.77 %
# N:
#   RMSE:   0.0472
#   NRMSE:  0.2846
#   MAPE:   3.80 %
# pH:
#   RMSE:   0.0897
#   NRMSE:  0.1121
#   MAPE:   1.07 %
#
# Métricas globales:
# AIC (nuevo modelo): -140.39
# BIC (nuevo modelo): -131.95
# AIC (modelo original): -81.49
# BIC (modelo original): -73.05
# RMSE (nuevo modelo): 0.1526
# RMSE (modelo original): 0.3186
# NMRSE (nuevo modelo): 0.0219
# NMRSE (modelo original): 0.0458
# MAPE (nuevo modelo): 5.02 %
# MAPE (modelo original): 9.97 %

# %% [markdown]
# # comparacion de modelos

# %%
# Original parameters
params_og = {
      't_lag': 7,
      'k_C': 0.3828,
      'k_N': 1.0027e-4, 
      'Y': {'X_C': 0.484,
      'X_N': 21.575, 
      'X_CO2': 0.3687}, 
      'Xmax': 1.4462,
      'mu_max': 0.19,
      'k_d': 0.001, 
      'pH': {'pka1': 6.86, # pKa of KH2PO4
            'pka2': 3.13,  # pka of C6H8O7
            'pka3': 4.76,  # pka of (C6H7O7)-
            'pka4': 6.40,  # pka of (C6H6O7)2-
            'pka5': 9.25,  # pka of NH3
            'pka6': 14.15, # pka of C3H8O3
            'pka7': 6.35,  # pka of CO2
            'pka8': 10.33, # pka of (HCO3)-
            'pka9': 14,    # pka of H2O
            'conc': {'KH2PO4': 2.18,
                  'C6H8O7': 2},
            'LL': 3.4687,
            'UL': 7.4,
            'alk': 7.2},
      'I_val': 4.0413,
      'pH_M': [0, 14]} 

# Parameters for saturated oxygen
params_oxygen = copy.deepcopy(params_og)
params_oxygen['Y']['X_O2'] = 1.352
params_oxygen['O2_sat'] = 0.007267
params_oxygen['k_La'] = 86.26
params_oxygen['k_O'] = 0.0045  

# Parameters for hypoxia
params_hypoxia = copy.deepcopy(params_og)
params_hypoxia['Y']['X_O2'] = 1.352
params_hypoxia['O2_sat'] = 0.007267
params_hypoxia['k_La'] = 5
params_hypoxia['k_O'] = 0.0045

# %%
# Experimental data

df_exp_v = pd.read_excel('DATA_APIYO.xlsx', sheet_name='Validation_n')
t_exp = df_exp_v['Time (hours)']
t_exp_v = df_exp_v['Time (hours)']
X_exp_v = df_exp_v['Biomass (g/L)']
C_exp_v = df_exp_v['Glycerol (g/L)']
N_exp_v = df_exp_v['Ammonia (g/L)']
ph_exp_v = df_exp_v['pH']
H_exp_v = df_exp_v['H']

# Initial conditions
X0 = X_exp_v[0]
c0 = C_exp_v[0]
n0 = N_exp_v[0]
co20 = 0.439 / 1000
o20 = 0.0001
z0 = ph_exp[0]  
x0 = np.array([X0, c0, n0, co20, o20, z0])

t_exp = np.linspace(0, 100, 501)
sol = simulate_model(p_norm, x0, params_values)

best_sim = sol['xf'].full().T  
solz = sol['zf'].full().T 

mu_values_casadi_adjusted = np.zeros_like(best_sim[:, 4])
for i in range(len(best_sim[:, 1])):
    mu_values_casadi_adjusted[i] = (
        p_norm[0] *
        (1 - np.exp(-t_casadi_O2[i] / params_values['t_lag'])) *
        (best_sim[:, 1][i] / (best_sim[:, 1][i] + params_values['k_C'])) *
        (best_sim[:, 2][i] / (best_sim[:, 2][i] + params_values['k_N'])) *
        (best_sim[:, 4][i] / (best_sim[:, 4][i] + params_values['k_O'])) *
        np.exp((params_values['I_val'] *
               ((solz[:, 0][i] - p_norm[1]) /
               (p_norm[1] - p_norm[2]))) ** 2) *
        (1 - best_sim[:, 0][i] / p_norm[3])
    )

# %% [markdown]
# ## OG model

# %%
def DAE_system_CasADi_OG(t, vars, z_algebraic, params):

    # Unpack variables
    X, C, N, CO2 = vars[0], vars[1], vars[2], vars[3]
    w = z_algebraic[0] # pH

    # Explicit algebraic equations
    # pH inhibition factor
    Iph = ca.exp((params['I_val'] * ((w - params['pH']['UL']) / (params['pH']['UL'] - params['pH']['LL']))) ** 2)

    # Specific growth rate
    mu = (params['mu_max'] 
          * (1 - ca.exp(-t / params['t_lag'])) 
          * (C / (C + params['k_C'])) 
          * (N / (N + params['k_N'])) 
          * (1 - (X / (params['Xmax']))) 
          * Iph)
    
    ka7 = 10 ** (-params['pH']['pka7'])
    
    # Differential equations
    dXdt   = (mu- params['k_d']) * X                                                     # Biomass
    dCdt   = - (mu / params['Y']['X_C']) * X                                             # Glycerol
    dNdt   = - (mu / params['Y']['X_N']) * X                                             # Ammonia
    dCO2dt = ((mu / params['Y']['X_CO2']) * X) - ka7 * (CO2 / (((10 ** -w) / ka7) + 1))  # CO2

    return ca.vertcat(dXdt, dCdt, dNdt, dCO2dt)

# %%
# Symbolic variables
t = ca.MX.sym('t')
x = ca.MX.sym('x', 4)  # [X, C, N, CO2]
z = ca.MX.sym('z')     # [pH]

# Systems's differential equations
dxdt = DAE_system_CasADi_OG(t, x, z, params_og)

# Algebraic equation
# Parameters
ka1 = 10 ** (-params_oxygen['pH']['pka1'])  # KH2PO4
ka2 = 10 ** (-params_oxygen['pH']['pka2'])  # C6H8O7
ka3 = 10 ** (-params_oxygen['pH']['pka3'])  # (C6H7O7)-
ka4 = 10 ** (-params_oxygen['pH']['pka4'])  # (C6H6O7)2-
ka7 = 10 ** (-params_oxygen['pH']['pka7'])  # CO2
ka9 = 10 ** (-params_oxygen['pH']['pka9'])  # H2O

H = 10 ** (-z) 

# Concentration of charges according to H+ ions
KHPO4 = params_oxygen['pH']['conc']['KH2PO4'] / ((H / ka1) + 1)
C6H5O7 = params_oxygen['pH']['conc']['C6H8O7'] / ((H ** 3 / (ka2 * ka3 * ka4)) + (H ** 2 / (ka3 * ka4)) + (H / ka4) + 1)
C6H6O7 = (H / ka4) * C6H5O7
C6H7O7 = (H / ka3) * C6H6O7
HCO3 = x[3] / ((H / ka7) + 1)
OH = ka9 / H

f_z = OH + HCO3 + KHPO4 + (3 * C6H5O7) + (2 * C6H6O7) + C6H7O7 - params_oxygen['pH']['alk'] - H

# CasADi function
f = ca.Function('f', [t, x, z], [dxdt])

# %%
# Initial conditions
X0 = 0.223
c0 = 5.922
n0 = 1.027
co20 = 0.439 / 1000
x0 = np.array([X0, c0, n0, co20])

z0 = np.array([0.0])  


tf = 100
n_steps = 500

t_values = np.linspace(0, tf, n_steps + 1)

# ODE system
dae = {'t': t, 'x': x, 'z': z, 'ode': f(t, x, z), 'alg': f_z}
integrator = ca.integrator('integrator', 'idas', dae, {'grid': t_values, 'output_t0': True})

# Solve
sol_casadi_OG = integrator(x0=x0, z0=z0)

# %%
# Extract results
t_casadi_og = np.linspace(0, 100, 501)
x_final_og = sol_casadi_OG['xf'].full().T
z_final_og = sol_casadi_OG['zf'].full().T

X_casadi_og = x_final_og[:, 0]
C_casadi_og = x_final_og[:, 1]
N_casadi_og = x_final_og[:, 2]
CO2_casadi_og = x_final_og[:, 3]
pH_casadi_og = z_final_og[:, 0]

# Compute specific growth rate over time
mu_values_casadi_og = np.zeros_like(C_casadi_og)
for i in range(len(C_casadi_og)):
    mu_values_casadi_og[i] = (
        params_og['mu_max'] *
        (1 - np.exp(-t_casadi_og[i] / params_og['t_lag'])) *
        (C_casadi_og[i] / (C_casadi_og[i] + params_og['k_C'])) *
        (N_casadi_og[i] / (N_casadi_og[i] + params_og['k_N'])) *
        np.exp((params_og['I_val'] *
               (pH_casadi_og[i] - params_og['pH']['UL']) /
               (params_og['pH']['UL'] - params_og['pH']['LL'])) ** 2) *
        (1 - X_casadi_og[i] / params_og['Xmax'])
    )

# %% [markdown]
# ## Saturated Oxygen

# %%
def DAE_system_CasADi_O2(t, vars, z_algebraic, params):

    # Unpack variables
    X, C, N, CO2, O = vars[0], vars[1], vars[2], vars[3], vars[4]
    w = z_algebraic[0] # pH

    # Explicit algebraic equations
    # pH inhibition factor
    Iph = ca.exp((params['I_val'] * ((w - params['pH']['UL']) / (params['pH']['UL'] - params['pH']['LL']))) ** 2)

    # Specific growth rate
    mu = (params['mu_max'] 
          * (1 - ca.exp(-t / params['t_lag'])) 
          * (C / (C + params['k_C'])) 
          * (N / (N + params['k_N'])) 
          * (O / (O + params['k_O']))
          * (1 - (X / (params['Xmax']))) 
          * Iph)
    
    ka7 = 10 ** (-params['pH']['pka7'])
    
    # Differential equations
    dXdt   = (mu- params['k_d']) * X                                                     # Biomass
    dCdt   = - (mu / params['Y']['X_C']) * X                                             # Glycerol
    dNdt   = - (mu / params['Y']['X_N']) * X                                             # Ammonia
    dCO2dt = ((mu / params['Y']['X_CO2']) * X) - ka7 * (CO2 / (((10 ** -w) / ka7) + 1))  # CO2
    dOdt   = params['k_La'] * (params['O2_sat'] - O) - (mu / params['Y']['X_O2']) * X    # O2

    return ca.vertcat(dXdt, dCdt, dNdt, dCO2dt, dOdt)

# %%
# Symbolic variables
t = ca.MX.sym('t')
x = ca.MX.sym('x', 5)  # [X, C, N, CO2, O2]
z = ca.MX.sym('z')     # [pH]

# Systems's differential equations
dxdt = DAE_system_CasADi_O2(t, x, z, params_oxygen)

# Algebraic equation
# Parameters
ka1 = 10 ** (-params_oxygen['pH']['pka1'])  # KH2PO4
ka2 = 10 ** (-params_oxygen['pH']['pka2'])  # C6H8O7
ka3 = 10 ** (-params_oxygen['pH']['pka3'])  # (C6H7O7)-
ka4 = 10 ** (-params_oxygen['pH']['pka4'])  # (C6H6O7)2-
ka7 = 10 ** (-params_oxygen['pH']['pka7'])  # CO2
ka9 = 10 ** (-params_oxygen['pH']['pka9'])  # H2O

H = 10 ** (-z) 

# Concentration of charges according to H+ ions
KHPO4 = params_oxygen['pH']['conc']['KH2PO4'] / ((H / ka1) + 1)
C6H5O7 = params_oxygen['pH']['conc']['C6H8O7'] / ((H ** 3 / (ka2 * ka3 * ka4)) + (H ** 2 / (ka3 * ka4)) + (H / ka4) + 1)
C6H6O7 = (H / ka4) * C6H5O7
C6H7O7 = (H / ka3) * C6H6O7
HCO3 = x[3] / ((H / ka7) + 1)
OH = ka9 / H

f_z = OH + HCO3 + KHPO4 + (3 * C6H5O7) + (2 * C6H6O7) + C6H7O7 - params_oxygen['pH']['alk'] - H

# CasADi function
f_O2 = ca.Function('f', [t, x, z], [dxdt])

# %%
# Initial conditions
X0 = 0.223
c0 = 5.922
n0 = 1.027
co20 = 0.439 / 1000
o20 = params_oxygen['O2_sat']
x0 = np.array([X0, c0, n0, co20, o20])

z0 = np.array([0.0])  # Initial guess for pH

# Final time and number of integration steps
tf = 100
n_steps = 500

# Simulation time vector
t_values = np.linspace(0, tf, n_steps + 1)

# ODE system
dae = {'t': t, 'x': x, 'z': z, 'ode': f_O2(t,x,z), 'alg': f_z}
integrator_O2 = ca.integrator('integrator', 'idas', dae, {'grid': t_values, 'output_t0': True})

# Solve
sol_casadi_O2 = integrator_O2(x0=x0, z0=z0)

# %%
# Extract results
t_casadi_O2 = np.linspace(0, 100, 501)
x_final_O2 = sol_casadi_O2['xf'].full().T
z_final_O2 = sol_casadi_O2['zf'].full().T

X_casadi_O2 = x_final_O2[:, 0]
C_casadi_O2 = x_final_O2[:, 1]
N_casadi_O2 = x_final_O2[:, 2]
CO2_casadi_O2 = x_final_O2[:, 3]
O2_casadi_O2 = x_final_O2[:, 4]
pH_casadi_O2 = z_final_O2[:, 0]

# Compute specific growth rate over time
mu_values_casadi_O2 = np.zeros_like(C_casadi_O2)
for i in range(len(C_casadi_O2)):
    mu_values_casadi_O2[i] = (
        params_oxygen['mu_max'] *
        (1 - np.exp(-t_casadi_O2[i] / params_oxygen['t_lag'])) *
        (C_casadi_O2[i] / (C_casadi_O2[i] + params_oxygen['k_C'])) *
        (N_casadi_O2[i] / (N_casadi_O2[i] + params_oxygen['k_N'])) *
        (O2_casadi_O2[i] / (O2_casadi_O2[i] + params_oxygen['k_O'])) *
        np.exp((params_oxygen['I_val'] *
               ((pH_casadi_O2[i] - params_oxygen['pH']['UL']) /
               (params_oxygen['pH']['UL'] - params_oxygen['pH']['LL']))) ** 2) *
        (1 - X_casadi_O2[i] / params_oxygen['Xmax'])
    )

# %% [markdown]
# ## Original Model vs O2 Model

# %%
colors = {
    'X': '#66C2A6',
    'C': '#FD8D62',
    'N': '#8DA0CB',
    'CO2': '#FED92F',
    'O2': '#A7D854',
    'pH': '#E78AC3',
    'mu': '#B3B3B3'
}

def darken_color(color, factor=0.6):
    rgb = mcolors.to_rgb(color)
    return tuple(factor * c for c in rgb)

fig, axes = plt.subplots(7, 1, figsize=(8, 14))

axes[0].plot(t_casadi_og, X_casadi_og, label='X CasADi base', color=colors['X'])
axes[0].plot(t_casadi_O2, X_casadi_O2, '--', label='X CasADi O2', color=darken_color(colors['X']))
axes[0].plot(t_exp, best_sim[:, 0],'-.', label='X Adjusted', color=colors['X'])
axes[0].scatter(t_exp_v, X_exp_v, label='Validation', color=darken_color(colors['X']), marker='o')
axes[0].set_title('Biomass (X)')
axes[0].set_xlabel('Time (h)')
axes[0].set_ylabel('X (g/L)')
axes[0].grid(True)
axes[0].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[1].plot(t_casadi_og, C_casadi_og, label='C CasADi base', color=colors['C'])
axes[1].plot(t_casadi_O2, C_casadi_O2, '--', label='C CasADi O2', color=darken_color(colors['C']))
axes[1].plot(t_exp, best_sim[:, 1],'-.', label='C Adjusted', color=colors['C'])
axes[1].scatter(t_exp_v, C_exp_v, label='Validation', color=darken_color(colors['C']), marker='s')
axes[1].set_title('Glycerol (C)')
axes[1].set_xlabel('Time (h)')
axes[1].set_ylabel('C (g/L)')
axes[1].grid(True)
axes[1].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[2].plot(t_casadi_og, N_casadi_og, label='N CasADi base', color=colors['N'])
axes[2].plot(t_casadi_O2, N_casadi_O2, '--', label='N CasADi O2', color=darken_color(colors['N']))
axes[2].plot(t_exp, best_sim[:, 2],'-.', label='N Adjusted', color=colors['N'])
axes[2].scatter(t_exp_v, N_exp_v, label='Validation', color=darken_color(colors['N']), marker='^')
axes[2].set_title('Ammonia (N)')
axes[2].set_xlabel('Time (h)')
axes[2].set_ylabel('N (g/L)')
axes[2].grid(True)
axes[2].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[4].plot(t_casadi_og, CO2_casadi_og, label='CO2 CasADi base', color=colors['CO2'])
axes[4].plot(t_casadi_O2, CO2_casadi_O2, '--', label='CO2 CasADi O2', color=darken_color(colors['CO2']))
axes[4].plot(t_exp, best_sim[:, 3],'-.', label='CO2 Adjusted', color=colors['CO2'])
axes[4].set_title('Carbon Dioxide (CO2)')
axes[4].set_xlabel('Time (h)')
axes[4].set_ylabel('CO2 (g/L)')
axes[4].grid(True)
axes[4].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[5].plot(t_casadi_O2, O2_casadi_O2, '--', label='O2 CasADi O2', color=darken_color(colors['O2']))
axes[5].plot(t_exp[1:], best_sim[1:,4],'-.', label='O2 Adjusted', color=colors['O2'])
axes[5].set_title('Dissolved Oxygen (O2)')
axes[5].set_xlabel('Time (h)')
axes[5].set_ylabel('O2 (g/L)')
axes[5].grid(True)
axes[5].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[3].plot(t_casadi_og, pH_casadi_og, label='pH CasADi base', color=colors['pH'])
axes[3].plot(t_casadi_O2, pH_casadi_O2, '--', label='pH CasADi O2', color=darken_color(colors['pH']))
axes[3].plot(t_exp, solz[:, 0],'-.', label='pH Adjusted', color=colors['pH'])
axes[3].scatter(t_exp_v, ph_exp_v, label='Validation', color=darken_color(colors['pH']), marker='*')
axes[3].set_title('pH')
axes[3].set_xlabel('Time (h)')
axes[3].set_ylabel('pH')
axes[3].grid(True)
axes[3].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

axes[6].plot(t_casadi_og, mu_values_casadi_og, label='μ CasADi base', color=colors['mu'])
axes[6].plot(t_casadi_O2, mu_values_casadi_O2, '--', label='μ CasADi O2', color=darken_color(colors['mu']))
axes[6].plot(t_exp, mu_values_casadi_adjusted, '-.', label='μ adjusted', color=darken_color(colors['mu']))
axes[6].set_title('Specific Growth Rate (μ)')
axes[6].set_xlabel('Time (h)')
axes[6].set_ylabel('μ (1/h)')
axes[6].grid(True)
axes[6].legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)

#fig.suptitle('Comparison between models', fontsize=16)
plt.tight_layout()
plt.show()
